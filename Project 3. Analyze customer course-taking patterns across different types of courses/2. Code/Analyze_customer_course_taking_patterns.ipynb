# %% [markdown]
# # **Introduction**

# %% [markdown]
# ## **1. 목표(가설) 설정**

# %% [markdown]
# - 분석범위:
#     - 2015년부터 2024년까지 각각의 4개 데이터 파일
# - 분석목표:
#     - 각 데이터별 특징 분석
#     - 2022년도 월별 각 데이터 추세 분석
# - 분석도구: 파이썬
# - 기대효과:
#     - 고객들의 강의 신청 유형 분석을 통한 고객별 강의할인 쿠폰, 이벤트 기획 등 가능
#     - 환불 고객이 많은 강의와 인기있는 강의 분석을 통한 고객유지 방안수립
#     - 회원 가입 후 마지막 로그인 분석을 통해 휴면 계정회원 이탈 방지 대책 수립가능

# %% [markdown]
# ## **2. 데이터 선정 및 분석**

# %% [markdown]
# ### **1) 데이터 수집**

# %% [markdown]
# - 강의 주문, 수강, 환불, 고객정보와 관련된 데이터들 수집
#    - order.csv, course.csv, refund.csv, customer.csv 데이터를 이용

# %% [markdown]
# ### **2) EDA (탐색적 데이터 분석) 및 데이터 정제 실시**

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\j\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\j\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\j\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\j\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\j\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\j\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# 데이터 분석에 필요한 pandas, numpy, matploylib, seaborn 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
# 5개 데이터 불러오기
order = pd.read_csv('order-9968.txt')
course = pd.read_csv('course-9968.csv')
customer = pd.read_csv('customer-9968.csv')
refund = pd.read_csv('refund-9968.csv')
user = pd.read_csv('user-9968.csv')

# %%
order.head()
# Out:
#         id   type      state        name           created_at  \
# 0  1600585  ORDER  COMPLETED  [30일 수강] 엑  2022-12-31 23:42:49
# 1  1600580  ORDER  COMPLETED  한번에 끝내는 재무  2022-12-31 23:39:01
# 2  1600579  ORDER  COMPLETED  네오아카데미 : 까  2022-12-31 23:38:31
# 3  1600577  ORDER  COMPLETED  백엔드 개발자를 위  2022-12-31 23:35:52
# 4  1600574  ORDER  COMPLETED  React Nati  2022-12-31 23:30:51
#
#             updated_at  customer_id  list_price  sale_price  discount_price  \
# 0  2022-12-31 23:42:52      1083679       10000           0           10000
# 1  2022-12-31 23:39:25       129176       40000       40000               0
# 2  2022-12-31 23:39:17      1072552       20000       10000           10000
# 3  2022-12-31 23:36:09      1083664       20000       20000           10000
# 4  2022-12-31 23:31:13      1033553       20000       20000               0
#
#    tax_free_price
# 0               0
# 1           40000
# 2           10000
# 3           20000
# 4           20000

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284035 entries, 0 to 284034
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              284035 non-null  int64
#  1   type            284035 non-null  object
#  2   state           284035 non-null  object
#  3   name            284035 non-null  object
#  4   created_at      284035 non-null  object
#  5   updated_at      284035 non-null  object
#  6   customer_id     284035 non-null  int64
#  7   list_price      284035 non-null  int64
#  8   sale_price      284035 non-null  int64
#  9   discount_price  284035 non-null  int64
#  10  tax_free_price  284035 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 23.8+ MB

# %%
# 각 컬럼별 결측치 수 확인
order.isnull().sum()
# Out:
# id                0
# type              0
# state             0
# name              0
# created_at        0
# updated_at        0
# customer_id       0
# list_price        0
# sale_price        0
# discount_price    0
# tax_free_price    0
# dtype: int64

# %%
course.head()
# Out:
#        id    type    state        created_at        updated_at  \
# 0  214903  COURSE  ONGOING   2022-12-27 1:33   2022-12-27 1:33
# 1  214898  COURSE  ONGOING  2022-12-26 12:25  2022-12-26 12:25
# 2  214897  COURSE  ONGOING  2022-12-26 12:20  2022-12-26 12:20
# 3  214896  COURSE  ONGOING  2022-12-26 12:17  2022-12-26 12:17
# 4  214895  COURSE  ONGOING  2022-12-26 12:14  2022-12-26 12:14
#
#                title description close_at  total_class_hours keywords
# 0  (B2G) K-Di-214903         NaN      NaN                NaN      NaN
# 1  (B2G) K-Di-214898         NaN      NaN                NaN      NaN
# 2  (B2G) K-Di-214897         NaN      NaN                NaN      NaN
# 3  (B2G) K-Di-214896         NaN      NaN                NaN      NaN
# 4  (B2G) K-Di-214895         NaN      NaN                NaN      NaN

# %%
course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 722 non-null    int64
#  1   type               722 non-null    object
#  2   state              722 non-null    object
#  3   created_at         722 non-null    object
#  4   updated_at         722 non-null    object
#  5   title              722 non-null    object
#  6   description        554 non-null    object
#  7   close_at           15 non-null     object
#  8   total_class_hours  578 non-null    float64
#  9   keywords           540 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 56.5+ KB

# %%
# 각 컬럼별 결측치 수 확인
course.isnull().sum()
# Out:
# id                     0
# type                   0
# state                  0
# created_at             0
# updated_at             0
# title                  0
# description          168
# close_at             707
# total_class_hours    144
# keywords             182
# dtype: int64

# %%
customer.head()
# Out:
#         id  type   state       created_at        updated_at  user_id  \
# 0  1482394  USER  NORMAL  2024/01/24 4:44  2024/01/24 13:54   959919
# 1  1482300  USER  NORMAL  2024/01/24 4:43   2024/01/25 6:10   818301
# 2  1482071  USER  NORMAL  2024/01/24 4:41   2024/01/25 7:46   543671
# 3  1445268  USER  NORMAL  2023/12/27 4:17   2023/12/27 4:17   824733
# 4  1445150  USER  NORMAL  2023/12/27 4:15   2023/12/27 4:15   767404
#
#            name       phone                           email
# 0  USER_1482394  1012345678  USER_1482394@notexistemail.com
# 1  USER_1482300  1012345678  USER_1482300@notexistemail.com
# 2  USER_1482071  1012345678  USER_1482071@notexistemail.com
# 3  USER_1445268  1012345678  USER_1445268@notexistemail.com
# 4  USER_1445150  1012345678  USER_1445150@notexistemail.com

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123013 entries, 0 to 123012
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          123013 non-null  int64
#  1   type        123013 non-null  object
#  2   state       123013 non-null  object
#  3   created_at  123013 non-null  object
#  4   updated_at  123013 non-null  object
#  5   user_id     123013 non-null  int64
#  6   name        123013 non-null  object
#  7   phone       123013 non-null  int64
#  8   email       123013 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 8.4+ MB

# %%
# 각 컬럼별 결측치 수 확인
customer.isnull().sum()
# Out:
# id            0
# type          0
# state         0
# created_at    0
# updated_at    0
# user_id       0
# name          0
# phone         0
# email         0
# dtype: int64

# %%
user.head()
# Out:
#         id  type   state           created_at           updated_at  \
# 0  1075089  USER  NORMAL  2022-12-31 23:39:19  2023-12-02 00:00:22
# 1  1075079  USER  NORMAL  2022-12-31 23:08:47  2023-12-03 23:34:39
# 2  1075074  USER  NORMAL  2022-12-31 22:46:31  2023-10-19 11:49:10
# 3  1075064  USER  NORMAL  2022-12-31 22:03:14  2023-10-06 18:20:51
# 4  1075059  USER  NORMAL  2022-12-31 21:35:42  2023-02-17 01:54:52
#
#          last_login_at username
# 0  2022-12-31 23:44:35     dkfk
# 1  2023-12-03 23:34:40     toqu
# 2  2023-10-19 11:49:10     theh
# 3  2023-10-06 18:20:51     tige
# 4  2023-02-17 01:54:52     kyg6

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122989 entries, 0 to 122988
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             122989 non-null  int64
#  1   type           122989 non-null  object
#  2   state          122989 non-null  object
#  3   created_at     122989 non-null  object
#  4   updated_at     122989 non-null  object
#  5   last_login_at  122989 non-null  object
#  6   username       122988 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 6.6+ MB

# %%
# 각 컬럼별 결측치 수 확인
user.isnull().sum()
# Out:
# id               0
# type             0
# state            0
# created_at       0
# updated_at       0
# last_login_at    0
# username         1
# dtype: int64

# %%
refund.head()
# Out:
#       id               type      state       created_at       updated_at  \
# 0  72124  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 7:29  2022-12-30 7:29
# 1  72121  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 7:01  2022-12-30 7:01
# 2  72119  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 6:08  2022-12-30 6:08
# 3  72117  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 6:00  2022-12-30 6:00
# 4  72116  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 5:57  2022-12-30 5:57
#
#      user_id  course_id  amount  tax_free_amount
# 0   619833.0   214323.0  -20000           -20000
# 1   146614.0   213905.0  -10000           -10000
# 2   541404.0   214402.0       0                0
# 3  1056095.0   203935.0  -10000           -10000
# 4    98880.0   213244.0  -20000           -20000

# %%
refund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12674 entries, 0 to 12673
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               12674 non-null  int64
#  1   type             12674 non-null  object
#  2   state            12674 non-null  object
#  3   created_at       12674 non-null  object
#  4   updated_at       12674 non-null  object
#  5   user_id          12659 non-null  float64
#  6   course_id        12075 non-null  float64
#  7   amount           12674 non-null  int64
#  8   tax_free_amount  12674 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 891.3+ KB

# %%
# 각 컬럼별 결측치 수 확인
refund.isnull().sum()
# Out:
# id                   0
# type                 0
# state                0
# created_at           0
# updated_at           0
# user_id             15
# course_id          599
# amount               0
# tax_free_amount      0
# dtype: int64

# %% [markdown]
# ## **Descriptive Analysis**

# %% [markdown]
# ### **3) 데이터 분석**

# %% [markdown]
# #### **(Order) 2022년 1월 중 가장 매출이 높았던 3일과 낮았던 3일 분석 (status = COMPLETED 기준)**

# %% [markdown]
# - 가장 매출이 높았던 3일은 1월 3일, 7일, 5일, 순이었으며, 가장 낮았던 3일은 1월 1일, 22일, 29일 순이었음.

# %%
# to_datetime 함수를 이용하여 create_at를 날짜형 데이터로 변환
order['created_at'] = pd.to_datetime(order['created_at'])

# %%
# 2022년 1월 데이터 필터링
jan_2022_data = order[(order['created_at'].dt.year == 2022) & (order['created_at'].dt.month == 1)]

# state가 'COMPLETED'인 데이터만 필터링
jan_2022_completed = jan_2022_data[jan_2022_data['state'] == 'COMPLETED']

# 날짜별 매출 합계 구하기
daily_sales = jan_2022_completed.groupby(jan_2022_completed['created_at'].dt.date)['list_price'].sum().reset_index()

# 중복된 날짜 제거
daily_sales = daily_sales.drop_duplicates(subset=['created_at'])

# 매출 기준으로 내림차순 정렬하여 가장 높은 매출을 가진 상위 3일 가져오기
top_3_days = daily_sales.nlargest(3, 'list_price')

# 매출 기준으로 오름차순 정렬하여 가장 낮은 매출을 가진 상위 3일 가져오기
bottom_3_days = daily_sales.nsmallest(3, 'list_price')

# 상위 3일과 하위 3일을 합쳐서 최종 결과 생성
result = pd.concat([top_3_days, bottom_3_days])

print("상위 3일과 하위 3일을 포함한 결과:")
print(result[['created_at', 'list_price']])
# Out:
# 상위 3일과 하위 3일을 포함한 결과:
#     created_at  list_price
# 2   2022-01-03    48980000
# 6   2022-01-07    34700000
# 4   2022-01-05    33840000
# 0   2022-01-01     6260000
# 21  2022-01-22     6850000
# 28  2022-01-29     8920000

# %% [markdown]
# #### **(Order) 2022년 1월 중 가장 매출이 높았던 3일과 낮았던 3일의 매출액(list_price)과, 주문 수, 신청자 수, 강의 수**

# %% [markdown]
# - 가장 매출이 높았던 3일
#     - 2022-01-03 48,980,000원, 2022-01-07 34,700,000원, 2022-01-05 33,840,000원
#     - 주문 수: 3,876개, 신청자 수: 4,444명,
# 강의 수: 971개
# - 가장 매출이 낮았던 3일
#     - 2022-01-01 6,260,000원,  2022-01-22 ,685,000원,   2022-01-29 , 89,200원
#     - 주문 수: 703개,
# 신청 수:787명 강의수:174개97

# %%
# 2022년 1월 데이터 필터링
jan_2022_data = order[(order['created_at'].dt.year == 2022) & (order['created_at'].dt.month == 1)]

# state가 'COMPLETED'인 데이터만 필터링
jan_2022_completed = jan_2022_data[jan_2022_data['state'] == 'COMPLETED']

# 날짜별 매출 합계 구하기
daily_sales = jan_2022_completed.groupby(jan_2022_completed['created_at'].dt.date)['list_price'].sum().reset_index()

# 중복된 날짜 제거
daily_sales = daily_sales.drop_duplicates(subset=['created_at'])

# 매출 기준으로 내림차순 정렬하여 가장 높은 매출을 가진 상위 3일 가져오기
top_3_days = daily_sales.nlargest(3, 'list_price')

# 매출 기준으로 오름차순 정렬하여 가장 낮은 매출을 가진 상위 3일 가져오기
bottom_3_days = daily_sales.nsmallest(3, 'list_price')

# 상위 3일과 하위 3일의 날짜 리스트
top_3_dates = top_3_days['created_at'].tolist()
bottom_3_dates = bottom_3_days['created_at'].tolist()

# 각 날짜별 주문 수, 신청자 수, 강의 수 계산
top_3_data = jan_2022_completed[jan_2022_completed['created_at'].dt.date.isin(top_3_dates)]
bottom_3_data = jan_2022_completed[jan_2022_completed['created_at'].dt.date.isin(bottom_3_dates)]

# 상위 3일과 하위 3일의 주문 수, 신청자 수, 강의 수 계산
top_3_order_count = top_3_data['customer_id'].nunique()
top_3_user_count = top_3_data['id'].nunique()
top_3_course_count = top_3_data['name'].nunique()

bottom_3_order_count = bottom_3_data['customer_id'].nunique()
bottom_3_user_count = bottom_3_data['id'].nunique()
bottom_3_course_count = bottom_3_data['name'].nunique()

print("가장 매출이 높은 3일:")
print(top_3_days[['created_at', 'list_price']])
print("\n주문 수:", top_3_order_count)
print("신청자 수:", top_3_user_count)
print("강의 수:", top_3_course_count)

print("\n가장 매출이 낮은 3일:")
print(bottom_3_days[['created_at', 'list_price']])
print("\n주문 수:", bottom_3_order_count)
print("신청자 수:", bottom_3_user_count)
print("강의 수:", bottom_3_course_count)
# Out:
# 가장 매출이 높은 3일:
#    created_at  list_price
# 2  2022-01-03    48980000
# 6  2022-01-07    34700000
# 4  2022-01-05    33840000
#
# 주문 수: 3876
# 신청자 수: 4444
# 강의 수: 197
#
# 가장 매출이 낮은 3일:
#     created_at  list_price
# 0   2022-01-01     6260000
# 21  2022-01-22     6850000
# 28  2022-01-29     8920000
#
# 주문 수: 703
# 신청자 수: 787
# 강의 수: 174

# %% [markdown]
# #### **(Order) 월별 각 강의 별 할인율 분석**

# %% [markdown]
# - 각 월별 각 강의별 할인율을 계산하였으며, 그 중 가장 높은 할인율을 가진 강의는 '[내부용]Apach' 으로 할인율은 200000.0.

# %%
# 각 월별 강의 별 할인율 계산
monthly_discount_rates = order.groupby([order['created_at'].dt.year, order['created_at'].dt.month, 'name'])['discount_price'].mean()

# 결과 출력
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(monthly_discount_rates)
# Out:
# created_at  created_at  name
# 2022        1           (B2B) 42SE          0.000000
#                         (B2B) K-Di      15000.000000
#                         (B2B) 디캠프           0.000000
#                         (B2B) 비바리퍼          0.000000
#                         (B2B) 빌리지베          0.000000
#                         (B2B) 와이즈셀          0.000000
#                         (B2B) 이지엠앤          0.000000
#                         (B2B) 주식회사          0.000000
#                         (B2B) 크몽 온          0.000000
#                         (B2B) 하나금융          0.000000
#                         100개의 클론디자       9255.813953
#                         100억을 움직이는       4396.135266
#                         13만 구독자 피피       8965.517241
#                         150만 원으로 월      10958.904110
#                         15명의 전문 애널      14102.564103
#                         2030을 위한 내       3800.000000
#                         30개 글감으로 에       4851.485149
#                         30개 프로젝트로        7969.543147
#                         3단계로 끝내는 직      12380.952381
#                         6개월 치 업무를        6923.076923
#                         A/B 테스트 탑재       7500.000000
#                         AI Explore          0.000000
#                         AI 온라인 컨퍼런      10000.000000
#                         Apache Spa       2500.000000
#                         C#과 유니티로 배       7428.571429
#                         C#으로 하는 인공      18333.333333
#                         C++ 실력 완성        8333.333333
#                         FAST MBA 2       7435.897436
#                         FX 아티스트 김재      11343.283582
#                         Financial        6971.428571
#                         GA4 탑재, 구글       6303.317536
#                         K-Digital       32666.666667
#                         Kafka 완전 정      10350.877193
#                         Kubernetes      11218.074656
#                         M&A 기업 및 기       8846.153846
#                         MSA 환경의 효율       4090.909091
#                         OpenCV를 활용       6800.000000
#                         Prometheus       7187.500000
#                         REC.ON : 자       5000.000000
#                         Realistic        9444.444444
#                         R을 활용한 퀀트       13428.571429
#                         Sales Coac       9833.333333
#                         THE RED :        1923.076923
#                         TensorFlow          0.000000
#                         The Front       10909.090909
#                         The RED :        4554.973822
#                         The RED: 조       3698.630137
#                         The Red :        3555.555556
#                         The Red: 2       3921.568627
#                         TypeScript      11204.819277
#                         UX Explore          0.000000
#                         [1강+2강] 페이          0.000000
#                         [9일 한정할인]        6666.666667
#                         [데이터 분석 기획          0.000000
#                         [묶음] 강필성의        1190.476190
#                         [묶음] 스프링러너          0.000000
#                         [부동산 세금 강의       8571.428571
#                         [조MD의 스마트스       8333.333333
#                         [증정 쿠폰 발급안       5925.925926
#                         [증정 쿠폰 즉시           0.000000
#                         [한정판매] 딥러닝          0.000000
#                         [한정판매] 자연어          0.000000
#                         iOS 앱 개발 올       6444.444444
#                         star741의 캐       9333.333333
#                         sudo : CTO       5688.073394
#                         sudo : Tec       2000.000000
#                         강필성의 머신러닝       13846.153846
#                         검색 최적화(SEO       7000.000000
#                         게임 개발자 취업의       9389.312977
#                         게임 캐릭터 모델링       9181.818182
#                         공여사와 무작정 풀       8012.422360
#                         구글 Materia       8235.294118
#                         구글 애널리틱스 올       2941.176471
#                         구글이 선택한 디자       7200.000000
#                         권오상의 금융 아카       5444.444444
#                         권오상의 재무분석           0.000000
#                         글로벌 엑스퍼트 :      10909.090909
#                         김기현의 BERT,       7142.857143
#                         김기현의 딥러닝을       15454.545455
#                         김동원의 저예산 마       7037.037037
#                         김민태의 프론트엔드       9684.210526
#                         나만의 애정하는 인      10800.000000
#                         나만의 특별한 일상       4651.162791
#                         나의 칼퇴치트키 엑       7405.063291
#                         나의 커리어 치트키       8235.294118
#                         네트워크와 보안 핵       8484.848485
#                         노잼봇과 함께 배우       9148.936170
#                         논리적인 디자인을        7500.000000
#                         뇌 성장과 정서사회      10000.000000
#                         누구나 가능한 VR       6220.472441
#                         누적 다운로드 12       7931.034483
#                         누적 조회수 12억      11315.789474
#                         다빈치리졸브로 배우       7625.000000
#                         데이터베이스와 SQ       2164.502165
#                         디벨로퍼에게 배우는       9425.287356
#                         디자이너 몰래 듣는       3179.190751
#                         디자인 기초 체력        3837.209302
#                         디자인의 차이를 만       4400.000000
#                         딥러닝을 활용한 추       9830.508475
#                         라이엇게임즈 TA에      11320.754717
#                         라이팅 마스터 클래          0.000000
#                         리눅스 실전 정복        7614.678899
#                         리더를 위한 HR/       6129.032258
#                         리마의 로맨스판타지       9819.277108
#                         매치무브 온보딩 :      11538.461538
#                         모델 성능 개선으로       9152.542373
#                         모두를 위한 앱 개      10344.827586
#                         모바일 UI 디자인       4666.666667
#                         모션그래픽 뉴패러다       7671.232877
#                         무기가 되는 데이터          0.000000
#                         바다가 알려주는 감      10967.741935
#                         바이블 : 파이썬        7068.965517
#                         바이오 데이터사이언      12000.000000
#                         바이트 디그리 :        2272.727273
#                         박담 작가와 함께       15172.413793
#                         박민수에게 배우는           0.000000
#                         박세익 전무에게 배      15000.000000
#                         박은종의 객체지향       10000.000000
#                         배곡파 작가의 실사       3852.691218
#                         부동산 디벨로퍼 올       6927.083333
#                         브랜딩 올인원 패키       7833.333333
#                         브랜딩을 담은 리빙      10156.250000
#                         블렌더로 만드는 동       8576.122673
#                         블렌더로 손쉽게 만       6853.932584
#                         블리자드 아티스트의       7054.794521
#                         사업 성패를 예측하       3571.428571
#                         사진 촬영 및 라이       9354.838710
#                         상가 대통령 김인만      14878.048780
#                         성공적인 UX를 위      10000.000000
#                         성립의 아이패드 오       6500.000000
#                         세상의 모든 감성        7364.620939
#                         세상의 모든 연필과      11555.555556
#                         소비자 리서치와 보       8000.000000
#                         수학적으로 접근하는      10851.063830
#                         스타트업 투자유치&       1818.181818
#                         스프링러너의 스프링       9791.666667
#                         스프링의 정석 :        7136.563877
#                         시크릿 코드 : 프          0.000000
#                         실리콘밸리 시리즈       13333.333333
#                         실리콘밸리 시리즈:       9473.684211
#                         실무 문제 해결을        7551.020408
#                         실전압축패키지 :        6428.571429
#                         십분만에 끝낸다 십       2209.302326
#                         아이패드로 그리는       11428.571429
#                         아카데미 : 편집하       9134.615385
#                         아파트 말고 부동산      11562.500000
#                         알고리즘 / 기술면       7488.372093
#                         애프터 이펙트 하나       6901.408451
#                         애프터이펙트 플러그      15625.000000
#                         애프터이펙트를 활용       6250.000000
#                         업계 TOP 세무사        952.380952
#                         연봉도 배우면 바뀐      15384.615385
#                         영상PD에게 배우는       6984.126984
#                         옥테인으로 만드는        8043.478261
#                         온라인 패키지 :        7359.413203
#                         올인원 패키지 :        8036.649215
#                         완전정복! 시각디자       8380.462725
#                         용호수의 돈 버는        8000.000000
#                         용호수의 입문+실전          0.000000
#                         유니티 게임 포트폴      10909.090909
#                         유니티캠퍼스 온라인       9078.947368
#                         이필성의 포토클래스       8296.703297
#                         인물 + 아이패드           0.000000
#                         인물 + 연필과 펜          0.000000
#                         인스타를 성장시킨        6379.310345
#                         일잘러 필수 스킬        5361.842105
#                         자유자재로 쓰는 태       6571.428571
#                         재무/세무 회계 실       3793.103448
#                         쟈니브로스에게 배우       4693.877551
#                         쟈니브로스의 영상           0.000000
#                         젊은 VC 심사역들       4444.444444
#                         조MD의 스마트스토      10977.443609
#                         주거용 수익형 부동      12500.000000
#                         직장인 회계 첫걸음       5892.857143
#                         직장인을 위한 파이       7037.037037
#                         직장인이 진짜 필요       4646.464646
#                         처음부터 시작하는        8163.265306
#                         초격차 패키지 :        8718.120805
#                         최성일의 코딩 초급       6538.461538
#                         캐글 1위와 풀어보       8571.428571
#                         코꼬마를 위한 코딩       3333.333333
#                         코딩 왕초보를 위한       5414.012739
#                         코딩 첫걸음 프로젝       9117.647059
#                         퀴즈처럼 풀면서 배       8947.368421
#                         클라우드를 활용한       10248.447205
#                         타이포그래피와 편집       7500.000000
#                         탄탄한 Animat       7142.857143
#                         통계와 엑셀을 활용       6219.512195
#                         파이썬을 활용한 데      10750.000000
#                         파이썬을 활용한 머          0.000000
#                         파이썬을 활용한 시       7966.101695
#                         파이썬을 활용한 이       8918.918919
#                         패스트캠퍼스 x 서          0.000000
#                         퍼포먼스 마케팅,        8648.648649
#                         편집녀 프리미어 끝          0.000000
#                         편집하는여자의 영상      10000.000000
#                         프로모션 : 202          0.000000
#                         프로모션 : And          0.000000
#                         프로모션 : MZ           0.000000
#                         프로모션 : 개발           0.000000
#                         프로모션 : 게임           0.000000
#                         프로모션 : 기초부          0.000000
#                         프로모션 : 데이터          0.000000
#                         프로모션 : 디자이          0.000000
#                         프로모션 : 디자인          0.000000
#                         프로모션 : 디지털          0.000000
#                         프로모션 : 매출아          0.000000
#                         프로모션 : 매출을          0.000000
#                         프로모션 : 미래의          0.000000
#                         프로모션 : 백엔드          0.000000
#                         프로모션 : 설득력          0.000000
#                         프로모션 : 세상의          0.000000
#                         프로모션 : 실무           0.000000
#                         프로모션 : 실습으          0.000000
#                         프로모션 : 실전으          0.000000
#                         프로모션 : 실제같          0.000000
#                         프로모션 : 영상에          0.000000
#                         프로모션 : 운영부          0.000000
#                         프로모션 : 웹디자          0.000000
#                         프로모션 : 인기           0.000000
#                         프로모션 : 일러스          0.000000
#                         프로모션 : 입문자          0.000000
#                         프로모션 : 전략부          0.000000
#                         프로모션 : 제대로          0.000000
#                         프로모션 : 주니어          0.000000
#                         프로모션 : 진짜보          0.000000
#                         프로모션 : 촬영부          0.000000
#                         프로모션 : 캐릭터          0.000000
#                         프로모션 : 투자           0.000000
#                         프로모션 : 프로그          0.000000
#                         프로모션 : 프로젝          0.000000
#                         프로모션 : 필수           0.000000
#                         프로모션 : 한 번          0.000000
#                         프로모션 : 핫한           0.000000
#                         프로모션 : 핵심만          0.000000
#                         프로모션 : 현업           0.000000
#                         프로모션 : 회사생          0.000000
#                         프로젝트와 함께 배      10400.000000
#                         하나금융티아이_DT          0.000000
#                         한 번에 끝내는 N       9090.909091
#                         한 번에 끝내는 P       6200.000000
#                         한 번에 끝내는 R       8813.559322
#                         한 번에 끝내는 S       9106.145251
#                         한 번에 끝내는 게      10909.090909
#                         한 번에 끝내는 데       6787.564767
#                         한 번에 끝내는 디       6268.656716
#                         한 번에 끝내는 딥       9320.594480
#                         한 번에 끝내는 머       7785.714286
#                         한 번에 끝내는 반       4782.608696
#                         한 번에 끝내는 부      11938.775510
#                         한 번에 끝내는 엑       6069.364162
#                         한 번에 끝내는 영      10441.176471
#                         한 번에 끝내는 유       9009.900990
#                         한 번에 끝내는 컴       7605.118830
#                         한 번에 끝내는 코       2310.030395
#                         한 번에 끝내는 파       8244.897959
#                         한 번에 끝내는 포       4827.586207
#                         한 번에 끝내는 프       6893.081761
#                         한번에 끝내는 3D       7230.046948
#                         한번에 끝내는 Ja       7156.133829
#                         한번에 끝내는 UX       6343.115124
#                         한번에 끝내는 VF      10000.000000
#                         한번에 끝내는 모션       7196.467991
#                         한번에 끝내는 재무      10800.000000
#                         해외소싱으로 온라인       4883.720930
#                         해외주식명저로 배우      13225.806452
#                         현직 Advisor      11538.461538
#                         현직 VC가 알려주       1929.824561
#                         확실하게 끝내는 포       6698.113208
#                         히어로부터 크리쳐까       8115.942029
#             2            [VOD+출판권]      11351.351351
#                         (B2B) K-Di      21956.521739
#                         (B2B) 대교 온          0.000000
#                         (B2B) 메디쿼터          0.000000
#                         (B2B) 비바리퍼          0.000000
#                         (B2B) 비소나이          0.000000
#                         (B2B) 삼성SD          0.000000
#                         (B2B) 아레나캐          0.000000
#                         (B2B) 에이블리          0.000000
#                         (B2B) 이투컬렉          0.000000
#                         (B2B) 인밸런스          0.000000
#                         (B2B) 지투알           0.000000
#                         (B2B) 트리탑파          0.000000
#                         (내부용) 현직 V     110000.000000
#                         *테스트 [4기-6          0.000000
#                         100개의 클론디자       7443.181818
#                         100억을 움직이는       1913.043478
#                         13만 구독자 피피      11142.857143
#                         150만 원으로 월       3589.743590
#                         15명의 전문 애널      18709.677419
#                         2030을 위한 내       8461.538462
#                         20가지 급락 이벤      13076.923077
#                         30개 글감으로 에       7088.607595
#                         30개 프로젝트로       10122.448980
#                         3단계로 끝내는 직      11250.000000
#                         4인4색 노하우로        8421.052632
#                         6개월 치 업무를        6969.696970
#                         A/B 테스트 탑재      20000.000000
#                         AI 온라인 컨퍼런          0.000000
#                         AI/Data Sc       5000.000000
#                         Apache Spa          0.000000
#                         C#과 유니티로 배       4857.142857
#                         C#으로 하는 인공      30000.000000
#                         C++ 실력 완성        9545.454545
#                         FAST MBA 2       6363.636364
#                         FX 아티스트 김재      14444.444444
#                         Fastcampus       8721.804511
#                         Financial        8490.566038
#                         GA4 탑재, 구글       5517.241379
#                         IREN의 배경과        7407.407407
#                         K-Digital       31904.761905
#                         Kafka 완전 정      15555.555556
#                         Kubernetes      13389.261745
#                         M&A 기업 및 기      18750.000000
#                         MSA 환경의 효율       5737.704918
#                         OpenCV를 활용      10312.500000
#                         Prometheus       8387.096774
#                         REC.ON : 자          0.000000
#                         Realistic        8048.780488
#                         R을 활용한 퀀트        5000.000000
#                         Sales Coac       4000.000000
#                         THE RED :           0.000000
#                         The RED :        1564.027370
#                         The RED: I       3617.021277
#                         The RED: 조          0.000000
#                         The Red :        1428.571429
#                         The Red: 2        714.285714
#                         TypeScript      23333.333333
#                         UX Explore       1250.000000
#                         Youtube 프로       1555.555556
#                         [100일 특강]           0.000000
#                         [1강+2강] 페이          0.000000
#                         [2개 강의 묶음]          0.000000
#                         [3개 강의 묶음]          0.000000
#                         [VOD+출판권]       12000.000000
#                         [내부용]Apach     200000.000000
#                         [데이터 분석 기획          0.000000
#                         [묶음] 강필성의           0.000000
#                         [묶음] 스프링러너          0.000000
#                         [정가]쟈니브로스의     100000.000000
#                         [조MD의 스마트스      18750.000000
#                         [증정 쿠폰 발급안      13600.000000
#                         [증정 쿠폰 즉시           0.000000
#                         [평생수강 강의]        6684.964928
#                         [프로모션] : 2          0.000000
#                         [프로모션] : U          0.000000
#                         [프로모션] : 개          0.000000
#                         [프로모션] : 기          0.000000
#                         [프로모션] : 누          0.000000
#                         [프로모션] : 데          0.000000
#                         [프로모션] : 디          0.000000
#                         [프로모션] : 미          0.000000
#                         [프로모션] : 삶          0.000000
#                         [프로모션] : 시          0.000000
#                         [프로모션] : 실          0.000000
#                         [프로모션] : 왕          0.000000
#                         [프로모션] : 입          0.000000
#                         [프로모션] : 전          0.000000
#                         [프로모션] : 주          0.000000
#                         [프로모션] : 탑          0.000000
#                         [프로모션] : 투          0.000000
#                         [프로모션] : 한          0.000000
#                         [한정판매] 딥러닝          0.000000
#                         [한정판매] 자연어          0.000000
#                         iOS 앱 개발 올      10588.235294
#                         star741의 캐       7130.434783
#                         sudo : Tec        555.555556
#                         ★기수강생 전용 상          0.000000
#                         강필성의 머신러닝       14666.666667
#                         게임 개발자 취업의       9230.769231
#                         게임 캐릭터 모델링       9090.909091
#                         공여사와 무작정 풀       6250.000000
#                         구글 Materia      13333.333333
#                         구글 애널리틱스 올      14666.666667
#                         구글이 선택한 디자        434.782609
#                         권오상의 금융 아카       6166.666667
#                         권오상의 재무분석           0.000000
#                         그로스 마케팅 올인      20000.000000
#                         글로벌 엑스퍼트 :       7272.727273
#                         김기현의 BERT,      12586.206897
#                         김기현의 딥러닝을       16315.789474
#                         김동원의 저예산 마       8235.294118
#                         김민태의 프론트엔드      10380.952381
#                         나만의 애정하는 인      16363.636364
#                         나만의 특별한 일상       2777.777778
#                         나의 칼퇴치트키 엑       5226.337449
#                         나의 커리어 치트키       4000.000000
#                         네트워크와 보안 핵      12941.176471
#                         노잼봇과 함께 배우       9117.647059
#                         논리적인 디자인을       15000.000000
#                         누구나 가능한 VR      11500.000000
#                         누적 다운로드 12      13666.666667
#                         누적 조회수 12억      11818.181818
#                         다빈치리졸브로 배우       5555.555556
#                         데이터베이스와 SQ       1538.461538
#                         디벨로퍼에게 배우는       8648.648649
#                         디자이너 몰래 듣는       4800.000000
#                         디자인 기초 체력       12500.000000
#                         디자인의 차이를 만      10000.000000
#                         딥러닝을 활용한 추       8571.428571
#                         라이엇게임즈 TA에       6600.000000
#                         라이팅 마스터 클래          0.000000
#                         리눅스 실전 정복       19047.619048
#                         리더를 위한 HR/       8000.000000
#                         리마의 로맨스판타지       9934.640523
#                         매치무브 온보딩 :      10454.545455
#                         모델 성능 개선으로       7692.307692
#                         모두를 위한 앱 개      11643.835616
#                         모바일 UI 디자인       9444.444444
#                         모션그래픽 뉴패러다       6404.494382
#                         바다가 알려주는 감       7333.333333
#                         바이블 : 파이썬       10000.000000
#                         박담 작가와 함께       20909.090909
#                         박민수에게 배우는           0.000000
#                         박세익 전무에게 배      10888.888889
#                         박은종의 객체지향       10769.230769
#                         배곡파 작가의 실사        466.666667
#                         부동산 디벨로퍼 올       4318.181818
#                         브랜딩 올인원 패키       5820.895522
#                         브랜딩을 담은 리빙      12500.000000
#                         블렌더로 만드는 동       6388.888889
#                         블렌더로 손쉽게 만      10428.571429
#                         블리자드 아티스트의       7883.597884
#                         사업 성패를 예측하        731.707317
#                         사진 촬영 및 라이       6250.000000
#                         상가 대통령 김인만      30000.000000
#                         성공적인 UX를 위       3000.000000
#                         성립의 아이패드 오       6285.714286
#                         세상의 모든 감성        8863.636364
#                         세상의 모든 연필과       9615.384615
#                         소비자 리서치와 보      15000.000000
#                         수학적으로 접근하는      10000.000000
#                         스타트업 투자유치&       3939.393939
#                         스프링러너의 스프링       8035.714286
#                         스프링의 정석 :        8014.184397
#                         시크릿 코드 : 프          0.000000
#                         실리콘밸리 시리즈       10000.000000
#                         실리콘밸리 시리즈:      10909.090909
#                         실무 문제 해결을       19090.909091
#                         실전압축패키지 :        2307.692308
#                         십분만에 끝낸다 십       3333.333333
#                         아이패드로 그리는        6166.666667
#                         아카데미 : 편집하       7575.757576
#                         아파트 말고 부동산      13000.000000
#                         알고리즘 / 기술면      11896.551724
#                         애프터 이펙트 하나       9636.363636
#                         애프터이펙트 플러그      14411.764706
#                         애프터이펙트를 활용       7894.736842
#                         업계 TOP 세무사      12857.142857
#                         연봉도 배우면 바뀐          0.000000
#                         영상PD에게 배우는       3333.333333
#                         옥테인으로 만드는       26666.666667
#                         온라인 패키지 :        8009.950249
#                         올인원 패키지 :       10658.682635
#                         완전정복! 시각디자      10326.086957
#                         용호수의 돈 버는       10000.000000
#                         용호수의 입문+실전          0.000000
#                         유니티 게임 포트폴      10588.235294
#                         유니티캠퍼스 온라인       9864.864865
#                         이필성의 포토클래스       7567.567568
#                         인물 + 아이패드           0.000000
#                         인물 + 연필과 펜          0.000000
#                         인스타를 성장시킨        6666.666667
#                         일잘러 필수 스킬        6134.969325
#                         자유자재로 쓰는 태       7777.777778
#                         재무/세무 회계 실       4347.826087
#                         쟈니브로스에게 배우       3896.103896
#                         쟈니브로스의 영상           0.000000
#                         젊은 VC 심사역들      10000.000000
#                         조MD의 스마트스토       5757.575758
#                         주거용 수익형 부동       6250.000000
#                         직장인 회계 첫걸음       1538.461538
#                         직장인을 위한 파이       6428.571429
#                         직장인이 진짜 필요       9278.350515
#                         처음부터 시작하는        6153.846154
#                         초격차 패키지 :       10065.288357
#                         최성일의 코딩 초급       7500.000000
#                         카콜의 가볍게 시작       3267.326733
#                         캐글 1위와 풀어보       7500.000000
#                         커리어 가이드 :           0.000000
#                         코꼬마를 위한 코딩       1904.761905
#                         코딩 왕초보를 위한       5373.134328
#                         퀴즈처럼 풀면서 배      12608.695652
#                         클라우드를 활용한       19577.464789
#                         타이포그래피와 편집      13214.285714
#                         탄탄한 Animat      16896.551724
#                         테크보이 워니의 파       4811.715481
#                         통계와 엑셀을 활용       9387.755102
#                         파이썬을 활용한 데      10000.000000
#                         파이썬을 활용한 시      11935.483871
#                         파이썬을 활용한 이       9090.909091
#                         퍼포먼스 마케팅,        5739.130435
#                         편집녀 프리미어 끝          0.000000
#                         편집하는여자의 영상       9600.000000
#                         프로모션 : 202          0.000000
#                         프로모션 : 개발자          0.000000
#                         프로모션 : 내 취          0.000000
#                         프로모션 : 데이터          0.000000
#                         프로모션 : 디자인          0.000000
#                         프로모션 : 디지털          0.000000
#                         프로모션 : 매출아          0.000000
#                         프로모션 : 매출을          0.000000
#                         프로모션 : 반복업          0.000000
#                         프로모션 : 백엔드          0.000000
#                         프로모션 : 설득력          0.000000
#                         프로모션 : 웹디자          0.000000
#                         프로모션 : 입문자          0.000000
#                         프로모션 : 전략부          0.000000
#                         프로모션 : 주니어          0.000000
#                         프로모션 : 진짜보          0.000000
#                         프로모션 : 한 번          0.000000
#                         프로젝트와 함께 배      11666.666667
#                         한 번에 끝내는 N       7058.823529
#                         한 번에 끝내는 P       6304.347826
#                         한 번에 끝내는 R      17073.170732
#                         한 번에 끝내는 S      12250.000000
#                         한 번에 끝내는 게      13000.000000
#                         한 번에 끝내는 데       4911.504425
#                         한 번에 끝내는 디       4733.333333
#                         한 번에 끝내는 딥      11803.278689
#                         한 번에 끝내는 머      10434.782609
#                         한 번에 끝내는 반       6875.000000
#                         한 번에 끝내는 부      17500.000000
#                         한 번에 끝내는 엑       2325.581395
#                         한 번에 끝내는 영       6086.956522
#                         한 번에 끝내는 유       8333.333333
#                         한 번에 끝내는 직      12000.000000
#                         한 번에 끝내는 컴       6919.431280
#                         한 번에 끝내는 코       3658.536585
#                         한 번에 끝내는 파      11857.142857
#                         한 번에 끝내는 포       8181.818182
#                         한 번에 끝내는 프       6349.480969
#                         한번에 끝내는 3D       8641.975309
#                         한번에 끝내는 Ja       9939.759036
#                         한번에 끝내는 UX       7285.714286
#                         한번에 끝내는 VF      10000.000000
#                         한번에 끝내는 모션       4309.392265
#                         한번에 끝내는 재무      12222.222222
#                         해외소싱으로 온라인      12500.000000
#                         해외주식명저로 배우      17857.142857
#                         현직 Advisor       7500.000000
#                         현직 VC가 알려주          0.000000
#                         확실하게 끝내는 포       2073.170732
#                         히어로부터 크리쳐까       8987.341772
#             3            [VOD+출판권]          0.000000
#                         (B2B) 42SE          0.000000
#                         (B2B) K-Di      16438.356164
#                         (B2B) 메이캔           0.000000
#                         (B2B) 비바리퍼          0.000000
#                         (B2B) 삼성SD          0.000000
#                         (B2B) 씽크에이          0.000000
#                         (B2B) 에쓰오일          0.000000
#                         (B2B) 엔디에스          0.000000
#                         (B2B) 주식회사          0.000000
#                         (B2B) 크레아코          0.000000
#                         (B2B) 피큐레잇          0.000000
#                         (B2B) 하나카드          0.000000
#                         (B2B) 화리상사          0.000000
#                         (내부용) 현직 V     110000.000000
#                         100개의 클론디자       6384.615385
#                         100억을 움직이는       3829.787234
#                         13만 구독자 피피       4500.000000
#                         150만 원으로 월       5641.025641
#                         15명의 전문 애널      17647.058824
#                         2030을 위한 내       8421.052632
#                         20가지 급락 이벤      10441.176471
#                         30개 글감으로 에       6296.296296
#                         30개 프로젝트로        8424.242424
#                         3단계로 끝내는 직       9090.909091
#                         4인4색 노하우로        7425.531915
#                         6개월 치 업무를        4769.230769
#                         AI 온라인 컨퍼런          0.000000
#                         Fastcampus      15897.435897
#                         Figma로 끝내는       8571.428571
#                         GA4 탑재, 구글          0.000000
#                         IREN의 배경과        7205.882353
#                         K-Digital       34666.666667
#                         Kafka 완전 정       8333.333333
#                         Kubernetes       8693.693694
#                         MSA 환경의 효율       3414.634146
#                         OpenCV를 활용       7011.494253
#                         Prometheus       3750.000000
#                         REC.ON : V          0.000000
#                         REC.ON : 자          0.000000
#                         Realistic        7142.857143
#                         THE RED :           0.000000
#                         The RED :        4380.776340
#                         The RED: I       5384.615385
#                         The Red :        1250.000000
#                         The Red:         1562.500000
#                         TypeScript      12777.777778
#                         UX Explore        526.315789
#                         Youtube 프로       5326.086957
#                         [12개월 구독제]       9000.000000
#                         [150일 기간제한          0.000000
#                         [180일 기간제한          0.000000
#                         [1강+2강] 페이          0.000000
#                         [2개 강의 묶음]          0.000000
#                         [3개 강의 묶음]          0.000000
#                         [60일특강 50%          0.000000
#                         [6개월 구독제]        2941.176471
#                         [VOD+출판권]           0.000000
#                         [내부용]Apach     200000.000000
#                         [묶음] 강필성의           0.000000
#                         [묶음] 스프링러너          0.000000
#                         [자유이용권] 강의          0.000000
#                         [정가]쟈니브로스의     100000.000000
#                         [조MD의 스마트스       7142.857143
#                         [증정 쿠폰 발급안      15000.000000
#                         [증정 쿠폰 즉시           0.000000
#                         [평생수강 강의]        7096.424702
#                         [프로모션] : A          0.000000
#                         [프로모션] : M          0.000000
#                         [프로모션] : 개          0.000000
#                         [프로모션] : 게          0.000000
#                         [프로모션] : 글          0.000000
#                         [프로모션] : 기          0.000000
#                         [프로모션] : 나          0.000000
#                         [프로모션] : 내          0.000000
#                         [프로모션] : 데          0.000000
#                         [프로모션] : 디          0.000000
#                         [프로모션] : 매          0.000000
#                         [프로모션] : 문          0.000000
#                         [프로모션] : 반          0.000000
#                         [프로모션] : 백          0.000000
#                         [프로모션] : 삶          0.000000
#                         [프로모션] : 설          0.000000
#                         [프로모션] : 손          0.000000
#                         [프로모션] : 시          0.000000
#                         [프로모션] : 실          0.000000
#                         [프로모션] : 아          0.000000
#                         [프로모션] : 업          0.000000
#                         [프로모션] : 영          0.000000
#                         [프로모션] : 왕          0.000000
#                         [프로모션] : 월          0.000000
#                         [프로모션] : 인          0.000000
#                         [프로모션] : 제          0.000000
#                         [프로모션] : 주          0.000000
#                         [프로모션] : 차          0.000000
#                         [프로모션] : 촬          0.000000
#                         [프로모션] : 탑          0.000000
#                         [프로모션] : 투          0.000000
#                         [프로모션] : 파          0.000000
#                         [프로모션] : 평          0.000000
#                         [프로모션] : 프          0.000000
#                         [프로모션] : 하          0.000000
#                         [프로모션] : 한          0.000000
#                         [프로모션] : 현          0.000000
#                         [한정판매] 딥러닝          0.000000
#                         [한정판매] 자연어          0.000000
#                         star741 기초          0.000000
#                         star741의 3       8191.489362
#                         sudo : Tec          0.000000
#                         test(2022년          0.000000
#                         강필성의 머신러닝       10000.000000
#                         게임 개발자 취업의          0.000000
#                         공여사와 무작정 풀          0.000000
#                         구글이 선택한 디자       3947.368421
#                         권오상의 금융 아카        570.175439
#                         글로벌 엑스퍼트 :       4375.000000
#                         김기현의 BERT,       5098.039216
#                         김기현의 딥러닝을        8333.333333
#                         김동원의 저예산 마       6486.486486
#                         김민태의 프론트엔드       8440.366972
#                         나만의 애정하는 인      13750.000000
#                         나만의 특별한 일상       5238.095238
#                         나의 칼퇴치트키 엑       7676.767677
#                         나의 커리어 치트키       5072.463768
#                         노잼봇과 함께 배우       7083.333333
#                         뇌 성장과 정서사회      10000.000000
#                         디벨로퍼에게 배우는      36666.666667
#                         라이엇게임즈 TA에      12222.222222
#                         라이팅 마스터 클래          0.000000
#                         리마의 로맨스판타지       6266.666667
#                         마디아의 UX/UI       5000.000000
#                         매치무브 온보딩 :      10000.000000
#                         머신러닝 최적화를       10000.000000
#                         모두를 위한 앱 개      10000.000000
#                         모션그래픽 뉴패러다       9206.349206
#                         문제은행 패키지 :       8000.000000
#                         바다가 알려주는 감       5652.173913
#                         바이블 : 파이썬       16666.666667
#                         박민수에게 배우는           0.000000
#                         박세익 전무에게 배          0.000000
#                         박은종의 객체지향       12857.142857
#                         배곡파 작가의 실사       4096.385542
#                         부동산 디벨로퍼 아      11538.461538
#                         브랜딩 올인원 패키       5833.333333
#                         브랜딩을 담은 리빙       5454.545455
#                         블렌더로 만드는 동       6976.320583
#                         블렌더로 손쉽게 만       8709.677419
#                         블리자드 아티스트의       8387.096774
#                         사업 성패를 예측하        731.707317
#                         상가 대통령 김인만       8571.428571
#                         성립의 아이패드 오       4117.647059
#                         세상의 모든 연필과      11363.636364
#                         스프링러너의 스프링      12105.263158
#                         스프링의 정석 :        7222.222222
#                         시크릿 코드 : 프          0.000000
#                         실리콘밸리 (1)        9687.500000
#                         실리콘밸리 시리즈:      12727.272727
#                         실무 문제 해결을       10400.000000
#                         실무 초밀착 리눅스       7853.107345
#                         십분만에 끝낸다 십          0.000000
#                         아이패드로 그리는        8571.428571
#                         알고리즘 / 기술면       7528.089888
#                         애프터 이펙트 하나      10400.000000
#                         애프터이펙트 플러그      13636.363636
#                         업계 TOP 세무사       5000.000000
#                         엑셀 실무 마스터       20000.000000
#                         연봉도 배우면 바뀐          0.000000
#                         연습문제 패키지 :      10000.000000
#                         영상PD에게 배우는       7500.000000
#                         옥테인으로 만드는       32000.000000
#                         온라인 패키지 :        7525.773196
#                         올인원 패키지 :        7079.579580
#                         올인원 패키지: 수       3461.538462
#                         올인원패키지 : 재       4444.444444
#                         완전정복! 시각디자      10000.000000
#                         왕초보를 위한 한        9128.205128
#                         용호수의 돈 버는        7317.073171
#                         용호수의 입문+실전          0.000000
#                         유니티캠퍼스 온라인       6521.739130
#                         이필성의 포토 클래          0.000000
#                         이필성의 포토클래스       7727.272727
#                         인물 + 아이패드           0.000000
#                         인물 + 연필과 펜          0.000000
#                         인스타를 성장시킨           0.000000
#                         쟈니브로스에게 배우       8333.333333
#                         쟈니브로스의 영상           0.000000
#                         조MD의 스마트스토       6842.105263
#                         직장인이 진짜 필요       6470.588235
#                         처음부터 시작하는        3333.333333
#                         초격차 패키지 :        7260.935910
#                         초격차 패키지 On          0.000000
#                         초격차 패키지: 3       8181.818182
#                         초격차 패키지: 한       9589.041096
#                         초격차패키지 : 한       9843.750000
#                         최성일의 코딩 초급       5882.352941
#                         카콜의 가볍게 시작        652.173913
#                         캐글 1위와 풀어보          0.000000
#                         코꼬마를 위한 코딩       3636.363636
#                         코딩 왕초보를 위한       5795.454545
#                         클라우드를 활용한       10533.333333
#                         탄탄한 Animat      16666.666667
#                         테크보이 워니의 파       7712.765957
#                         통계와 엑셀을 활용       5689.655172
#                         퍼포먼스 마케팅,        9080.459770
#                         편집녀 프리미어 끝          0.000000
#                         편집하는여자의 영상       8099.688474
#                         프로모션 : And          0.000000
#                         프로모션 : MZ           0.000000
#                         프로모션 : 개발부          0.000000
#                         프로모션 : 개발자          0.000000
#                         프로모션 : 게임개          0.000000
#                         프로모션 : 기초부          0.000000
#                         프로모션 : 나에게          0.000000
#                         프로모션 : 내 집          0.000000
#                         프로모션 : 내 취          0.000000
#                         프로모션 : 데이터          0.000000
#                         프로모션 : 디자인          0.000000
#                         프로모션 : 매출아          0.000000
#                         프로모션 : 문제해          0.000000
#                         프로모션 : 반복업          0.000000
#                         프로모션 : 백엔드          0.000000
#                         프로모션 : 설득력          0.000000
#                         프로모션 : 신입사          0.000000
#                         프로모션 : 실무           0.000000
#                         프로모션 : 실무에          0.000000
#                         프로모션 : 실습으          0.000000
#                         프로모션 : 영상에          0.000000
#                         프로모션 : 월급을          0.000000
#                         프로모션 : 인기           0.000000
#                         프로모션 : 인정받          0.000000
#                         프로모션 : 일러스          0.000000
#                         프로모션 : 제대로          0.000000
#                         프로모션 : 진짜보          0.000000
#                         프로모션 : 촬영부          0.000000
#                         프로모션 : 투자는          0.000000
#                         프로모션 : 프로젝          0.000000
#                         프로모션 : 한 번          0.000000
#                         프로모션 : 한끗으          0.000000
#                         프로모션 : 현업           0.000000
#                         한 번에 끝내는 N       5652.173913
#                         한 번에 끝내는 P       3043.478261
#                         한 번에 끝내는 S       9843.750000
#                         한 번에 끝내는 데       6866.666667
#                         한 번에 끝내는 디       5000.000000
#                         한 번에 끝내는 반       5714.285714
#                         한 번에 끝내는 부      10309.278351
#                         한 번에 끝내는 유          0.000000
#                         한 번에 끝내는 직       6047.904192
#                         한 번에 끝내는 컴       7786.259542
#                         한 번에 끝내는 코          0.000000
#                         한 번에 끝내는 파          0.000000
#                         한 번에 끝내는 프       7863.636364
#                         한번에 끝내는 3D          0.000000
#                         한번에 끝내는 모션          0.000000
#                         한번에 끝내는 부동      23333.333333
#                         합격 패스 : 데이        569.105691
#                         해외주식명저로 배우      26000.000000
#                         확실하게 끝내는 포       5487.804878
#                         히어로부터 크리쳐까       9473.684211
#             4            K-Digital          0.000000
#                         (B2B) 42SE          0.000000
#                         (B2B) K-Di      20714.285714
#                         (B2B) kt알파          0.000000
#                         (B2B) 라이노박          0.000000
#                         (B2B) 비바리퍼          0.000000
#                         (B2B) 빌리지베          0.000000
#                         (B2B) 씽크에이          0.000000
#                         (B2B) 엔디에스          0.000000
#                         (B2B) 칸투칸           0.000000
#                         (B2B) 크몽 온          0.000000
#                         (B2B) 하나금융          0.000000
#                         (B2B) 하나카드          0.000000
#                         (B2B)K-Dig      30000.000000
#                         (컨닝패드 증정)        2476.190476
#                         100개의 클론디자       5769.230769
#                         100억을 움직이는       2432.432432
#                         10년차 패션 MD       4615.384615
#                         13만 구독자 피피       1590.909091
#                         150만 원으로 월       6562.500000
#                         15명의 전문 애널      16896.551724
#                         2030을 위한 내      14000.000000
#                         20가지 급락 이벤      10232.558140
#                         30개 글감으로 에       9393.939394
#                         30개 프로젝트로        7167.138810
#                         3단계로 끝내는 직      11875.000000
#                         4인4색 노하우로        5681.818182
#                         6개월 치 업무를        6666.666667
#                         9 in 1 직장인       8235.294118
#                         A/B 테스트 탑재       7142.857143
#                         AI 온라인 컨퍼런      10000.000000
#                         C#과 유니티로 배       3571.428571
#                         C#으로 하는 인공      10000.000000
#                         C++ 실력 완성       11000.000000
#                         CLASS : 아기       2439.024390
#                         CLASS : 연필       5800.000000
#                         CLASS : 초보        666.666667
#                         FX 아티스트 김재       5357.142857
#                         Fastcampus      10000.000000
#                         Figma로 끝내는       2549.019608
#                         Financial        4883.720930
#                         GA4 탑재, 구글       3233.532934
#                         IREN의 배경과        5312.500000
#                         K-Digital       31904.761905
#                         Kafka 완전 정      13000.000000
#                         Kubernetes       7403.314917
#                         M&A 기업 및 기       4242.424242
#                         MSA 환경의 효율       7692.307692
#                         OUKO의 논리에        5897.435897
#                         OpenCV를 활용       6153.846154
#                         Prometheus       8095.238095
#                         REC.ON : 자          0.000000
#                         Realistic        6428.571429
#                         R을 활용한 퀀트        9875.000000
#                         Sales Coac       4090.909091
#                         THE RED :         333.333333
#                         The RED :        3182.897862
#                         The RED: I      10000.000000
#                         The RED: 조       4583.333333
#                         The Red :        7074.829932
#                         The Red: 2       7647.058824
#                         The Red: F       8421.052632
#                         The red :        2551.020408
#                         TypeScript      18000.000000
#                         Youtube 프로       5869.565217
#                         [12개월 구독제]      10267.716535
#                         [150일 기간제한        232.558140
#                         [180일 기간제한       1153.846154
#                         [1강+2강] 페이          0.000000
#                         [2개 강의 묶음]          0.000000
#                         [3개 강의 묶음]          0.000000
#                         [6개월 구독제]       34482.758621
#                         [VOD+출판권]           0.000000
#                         [~12/31 한정       2363.636364
#                         [균일가 100일           0.000000
#                         [내부용]Apach     200000.000000
#                         [런칭기념 한정특가       6000.000000
#                         [묶음] 강필성의           0.000000
#                         [증정 쿠폰 발급안       6666.666667
#                         [증정 쿠폰 즉시           0.000000
#                         [직장내일 콘텐츠       20000.000000
#                         [프로모션] : A          0.000000
#                         [프로모션] : M          0.000000
#                         [프로모션] : 개          0.000000
#                         [프로모션] : 게          0.000000
#                         [프로모션] : 글          0.000000
#                         [프로모션] : 기          0.000000
#                         [프로모션] : 나          0.000000
#                         [프로모션] : 내          0.000000
#                         [프로모션] : 데          0.000000
#                         [프로모션] : 디          0.000000
#                         [프로모션] : 막          0.000000
#                         [프로모션] : 매          0.000000
#                         [프로모션] : 문          0.000000
#                         [프로모션] : 반          0.000000
#                         [프로모션] : 백          0.000000
#                         [프로모션] : 베          0.000000
#                         [프로모션] : 삶          0.000000
#                         [프로모션] : 설          0.000000
#                         [프로모션] : 시          0.000000
#                         [프로모션] : 실          0.000000
# ...
#                         글로벌 연사와 함께          0.000000
#                         글로벌 탑티어 헤지      18000.000000
#                         글로벌 판매 1위       13076.923077
#                         기초부터 실무까지           0.000000
#                         기초부터 심화까지           0.000000
#                         기초부터 포트폴리오          0.000000
#                         김기현의 BERT,       2333.333333
#                         김기현의 딥러닝을        5714.285714
#                         김동원의 저예산 마      10263.157895
#                         김민태의 프론트엔드      11851.851852
#                         나만의 애정하는 인      20000.000000
#                         나만의 작품으로 작          0.000000
#                         나만의 캐릭터가 모          0.000000
#                         나만의 특별한 일상       5000.000000
#                         나에게 맞는 기업찾          0.000000
#                         나의 커리어 치트키      10625.000000
#                         내 취향 캐릭터 내          0.000000
#                         네오아카데미 : 까       7195.121951
#                         네오아카데미 : 대          0.000000
#                         네오아카데미 : 설      13333.333333
#                         네오아카데미 : 완       7990.867580
#                         네오아카데미 : 킨       7971.014493
#                         네오아카데미: 3명       8333.333333
#                         네오아카데미: 설의      16458.333333
#                         네오아카데미: 오카      19534.883721
#                         네오아카데미: 프로      11612.903226
#                         네오아카데미: 후와      15408.163265
#                         네트워크와 보안 핵       9787.234043
#                         노잼봇과 함께 배우      11538.461538
#                         논리적인 디자인을       19090.909091
#                         뇌 성장과 정서사회      30000.000000
#                         누구나 가능한 VR      11923.076923
#                         누적 다운로드 12      13333.333333
#                         누적 조회수 12억      15000.000000
#                         다빈치리졸브로 배우       9565.217391
#                         다양한 채색법을 배          0.000000
#                         단 1개월 만에 네       3333.333333
#                         닷밀 미디어아트 그       8809.523810
#                         닷밀의 미디어아트        8709.677419
#                         대기업 연봉 편집자          0.000000
#                         대체 불가한 브랜드          0.000000
#                         더욱 다채로운 비쥬          0.000000
#                         데이터 분석을 위한       3186.813187
#                         데이터 사이언스 A          0.000000
#                         돈 버는 전자책 작       3333.333333
#                         디마스 : 2023        238.095238
#                         디벨로퍼에게 배우는      14000.000000
#                         디자이너 몰래 듣는       3272.727273
#                         디자인 기초 체력       20000.000000
#                         디자인 기초체력 U          0.000000
#                         디자인의 차이를 만      11111.111111
#                         디테일을 남다르게!          0.000000
#                         딥러닝/머신러닝을       11145.833333
#                         딥러닝·인공지능 S      11054.313099
#                         라이엇게임즈 TA에      12222.222222
#                         라이팅 마스터 클래          0.000000
#                         랜선사수 피도리와        9292.929293
#                         리눅스 실전 정복        9487.179487
#                         리더를 위한 HR/      10666.666667
#                         리마의 로맨스판타지      18181.818182
#                         리얼리스틱&스타일라          0.000000
#                         리코더팩토리와 함께      11612.903226
#                         마디아의 UX/UI      11363.636364
#                         마케팅 기획법             0.000000
#                         막막함 덜어드려요!          0.000000
#                         매력적인 모델링과        7222.222222
#                         매력적인 미소녀 드          0.000000
#                         매출아 올라라! 퍼          0.000000
#                         매출을 높여주는 직          0.000000
#                         매치무브 온보딩 :      17500.000000
#                         머신러닝 최적화를       18333.333333
#                         명화 같은 비주얼의          0.000000
#                         모델 구현으로 끝내       9589.041096
#                         모델 성능 개선으로       9642.857143
#                         모두를 위한 앱 개      11081.081081
#                         모바일 UI 디자인       8666.666667
#                         문서의 신이 알려주       5892.857143
#                         문제해결을 위한 핵          0.000000
#                         미국주식 사관학교           0.000000
#                         바다가 알려주는 감       6666.666667
#                         바이블 : 파이썬        4000.000000
#                         박담 작가와 함께       13750.000000
#                         박민수에게 배우는           0.000000
#                         박세익 전무에게 배      24000.000000
#                         박은종의 객체지향       14782.608696
#                         반복업무는 STOP          0.000000
#                         배곡파 작가의 실사       7500.000000
#                         배우자마자 복습하는          0.000000
#                         백엔드 개발 마스터      14230.769231
#                         백엔드 개발의 완전          0.000000
#                         백엔드 개발자를 위       8368.983957
#                         베이직부터 완전 정          0.000000
#                         복사 & 붙여넣기로          0.000000
#                         부동산 디벨로퍼 올      11111.111111
#                         부동산 투자 올인원      20000.000000
#                         브랜딩을 담은 리빙      17142.857143
#                         블렌더로 만드는 동      10600.000000
#                         블렌더로 손쉽게 만      13333.333333
#                         블리자드 아티스트의      11923.076923
#                         비전공 개발자, 사          0.000000
#                         비전공자도 이해할        3333.333333
#                         빅데이터분석기사 실          0.000000
#                         빠르게 배운다! 직          0.000000
#                         빵형의 수학 없이        5849.056604
#                         사랑스러운 캐릭터           0.000000
#                         사무실의 그 누구도       5000.000000
#                         사이드 프로젝트 :       9803.921569
#                         사진 촬영 및 라이       6923.076923
#                         상가 대통령 김인만      45000.000000
#                         상상력을 펼쳐라 모          0.000000
#                         색감 마스터 까나&          0.000000
#                         설득력을 높이는 디          0.000000
#                         설레는 색감과 빛의      15862.068966
#                         성공적인 UX를 위       5714.285714
#                         성공적인 이직을 위          0.000000
#                         성립의 아이패드 오       3333.333333
#                         세상의 모든 감성       13181.818182
#                         세상의 모든 연필과      15714.285714
#                         수학적으로 접근하는      10000.000000
#                         스타트업 마케터로       11111.111111
#                         스타트업 채용 입문          0.000000
#                         스타트업 투자유치&       4838.709677
#                         스프링러너의 스프링       8888.888889
#                         스프링의 정석 :        8900.523560
#                         슬기로운 엑셀생활           0.000000
#                         시그니처 패키지 :       9560.439560
#                         시선을 사로잡는 영          0.000000
#                         시작부터 끝까지 함          0.000000
#                         신입사원 필수 수강          0.000000
#                         실리콘밸리 시리즈        9666.666667
#                         실리콘밸리 시리즈:       5000.000000
#                         실무 문제 해결을       16666.666667
#                         실무 사례로 배우는      11666.666667
#                         실무 초밀착 리눅스      10000.000000
#                         실무 프로젝트로 배      11111.111111
#                         실무 프로젝트와 모      11686.746988
#                         실무 활용 극대화를      12195.121951
#                         실패 없이 완주하는       6393.442623
#                         십분만에 끝낸다 십       6956.521739
#                         아이패드로 그리는       10476.190476
#                         아직 잘 알려지지        3333.333333
#                         아카데미 : 편집하      10697.674419
#                         아파트 말고 부동산      19000.000000
#                         압도적인 커리큘럼!          0.000000
#                         압도적인 퀄리티의           0.000000
#                         애프터 이펙트 하나      13333.333333
#                         애프터이펙트 플러그      30000.000000
#                         애프터이펙트를 활용       8695.652174
#                         어떤 툴도 완벽 마          0.000000
#                         업계 TOP 세무사      16363.636364
#                         연봉도 배우면 바뀐        769.230769
#                         영상PD에게 배우는       9782.608696
#                         영화&드라마에서 보          0.000000
#                         영화&드라마에서만           0.000000
#                         옥테인으로 만드는       10000.000000
#                         온라인 패키지 :        7840.909091
#                         올인원 패키지 :        9856.557377
#                         완전정복! 시각디자      11956.521739
#                         왕 초보도 쉽게 배          0.000000
#                         왕초보 강력 추천!          0.000000
#                         왕초보 신입 사원을          0.000000
#                         왕초보 입문자를 위          0.000000
#                         왕초보를 위한 머신          0.000000
#                         왕초보를 위한 앱           0.000000
#                         왕초보를 위한 한        8297.872340
#                         용호수의 돈 버는        9318.181818
#                         월급을 뛰어넘는 똑          0.000000
#                         유니티 게임 포트폴      16956.521739
#                         유니티캠퍼스 온라인      17777.777778
#                         유튜브 데뷔 10분          0.000000
#                         의료 데이터를 활용       8923.076923
#                         이규원의 TDD 아          0.000000
#                         이필성의 포토클래스      10588.235294
#                         인물 + 연필과 펜          0.000000
#                         인스타를 성장시킨        9729.729730
#                         일잘러 필수 스킬        7863.013699
#                         입문자를 위한 딥러      16956.521739
#                         입문자를 위한 풀스       6393.442623
#                         자유자재로 쓰는 태       5000.000000
#                         재무/세무 회계 실       7948.717949
#                         쟈니브로스에게 배우       8571.428571
#                         쟈니브로스의 영상           0.000000
#                         젊은 VC 심사역들       3636.363636
#                         점으로 완성하는 특      16666.666667
#                         정교함이 남다른 게          0.000000
#                         조MD의 스마트스토      13947.368421
#                         주거용 수익형 부동      10000.000000
#                         주니어 개발자를 위          0.000000
#                         주목받는 미래기술           0.000000
#                         지금 시작하는 프론          0.000000
#                         지금 우리 일상을       20000.000000
#                         직장인 회계 첫걸음       7826.086957
#                         직장인을 위한 파이      10000.000000
#                         직장인이 진짜 필요       8392.857143
#                         집에 있는 카메라로      13720.930233
#                         차근차근 따라하는        1166.666667
#                         차별화된 디자이너를          0.000000
#                         차원이 다른 캐주얼       8857.142857
#                         차이를 만드는 한           0.000000
#                         처음부터 시작하는        3478.260870
#                         초격차 시그니처 :       9867.549669
#                         초격차 패키지 :        9365.853659
#                         초격차 패키지: 3      10370.370370
#                         초격차 패키지: 한       9761.904762
#                         초단기 완성 : 1        434.782609
#                         초보 마케터들을 위          0.000000
#                         초보자를 전문가로        3333.333333
#                         최성일의 코딩 초급      11764.705882
#                         추억을 남기는 여행          0.000000
#                         취미로 부캐만들기           0.000000
#                         카콜의 가볍게 시작       7500.000000
#                         캐글 1위와 풀어보       7142.857143
#                         캐주얼 일러스트 드          0.000000
#                         커리어 High u          0.000000
#                         커리어 탑 선배가           0.000000
#                         컴퓨터 비전 정주행      15161.290323
#                         코꼬마를 위한 코딩      20000.000000
#                         코딩 왕초보를 위한       9473.684211
#                         코딩18: 웹개발       50000.000000
#                         쿠팡 마켓플레이스       10000.000000
#                         퀴즈처럼 풀면서 배      12400.000000
#                         클라우드를 활용한       13636.363636
#                         타이포그래피와 편집      12608.695652
#                         탄탄한 Animat      10000.000000
#                         테크보이 워니의 파      10000.000000
#                         투자 멘토에게 배우          0.000000
#                         파이썬?자바? 모두          0.000000
#                         파이썬으로 할 수        3723.404255
#                         파이썬을 활용한 데       9166.666667
#                         파이썬을 활용한 이      14444.444444
#                         패스트캠퍼스 개발       97343.957503
#                         퍼포먼스 마케팅,        6875.000000
#                         편집녀 애프터이펙트          0.000000
#                         편집녀 프리미어 끝          0.000000
#                         편집녀 프리미어+애          0.000000
#                         편집하는여자의 영상      11075.268817
#                         평범한 일상도 재미          0.000000
#                         포트폴리오까지 완성          0.000000
#                         프로모션 : 올인원       8035.714286
#                         프로젝트로 배우는           0.000000
#                         프로젝트에 바로 쓰          0.000000
#                         프로젝트와 함께 배      13200.000000
#                         프론트엔드 개발자가          0.000000
#                         프론트엔드 웹 개발       7045.454545
#                         프리프로덕션부터 배       3333.333333
#                         플러스엑스 UX 실       7193.308550
#                         플러스엑스 UX 팀      93438.256659
#                         피 튀기는 주식 투          0.000000
#                         한 권에 끝내는 I          0.000000
#                         한 권으로 끝내는           0.000000
#                         한 끝으로 디자인           0.000000
#                         한 번에 끝내는 A      12000.000000
#                         한 번에 끝내는 F       6692.913386
#                         한 번에 끝내는 H       2181.818182
#                         한 번에 끝내는 J          0.000000
#                         한 번에 끝내는 N      13620.689655
#                         한 번에 끝내는 P       8153.846154
#                         한 번에 끝내는 R      13000.000000
#                         한 번에 끝내는 S       8661.417323
#                         한 번에 끝내는 개          0.000000
#                         한 번에 끝내는 게      12352.941176
#                         한 번에 끝내는 구       2921.348315
#                         한 번에 끝내는 데       7516.198704
#                         한 번에 끝내는 동       6417.910448
#                         한 번에 끝내는 딥       6022.727273
#                         한 번에 끝내는 머       9191.176471
#                         한 번에 끝내는 반      12000.000000
#                         한 번에 끝내는 부      11413.612565
#                         한 번에 끝내는 블      11417.910448
#                         한 번에 끝내는 서       6687.898089
#                         한 번에 끝내는 엑      10952.380952
#                         한 번에 끝내는 웹          0.000000
#                         한 번에 끝내는 유      10416.666667
#                         한 번에 끝내는 직      10454.545455
#                         한 번에 끝내는 취          0.000000
#                         한 번에 끝내는 컴      10840.336134
#                         한 번에 끝내는 코       8470.588235
#                         한 번에 끝내는 퀀       9109.947644
#                         한 번에 끝내는 파      11025.641026
#                         한 번에 끝내는 포      11666.666667
#                         한 번에 끝내는 프       9271.844660
#                         한번에 끝내는 3D       9117.647059
#                         한번에 끝내는 ES       4761.904762
#                         한번에 끝내는 Ja      10569.620253
#                         한번에 끝내는 UX       9064.748201
#                         한번에 끝내는 VF      14444.444444
#                         한번에 끝내는 공간       8623.853211
#                         한번에 끝내는 디자      11590.909091
#                         한번에 끝내는 모션       9454.545455
#                         한번에 끝내는 재무      10227.272727
#                         합격을 부르는 매력          0.000000
#                         합격의 하이패스 :        243.902439
#                         해오의 입문자를 위          0.000000
#                         해외주식명저로 배우      22500.000000
#                         혁펜하임의 AI D       6577.181208
#                         혁펜하임의 DEEP          0.000000
#                         현업 프로젝트로 배          0.000000
#                         현직 Advisor       4285.714286
#                         화사한 색감과 빛의       8333.333333
#                         확실하게 끝내는 포       9166.666667
#                         히어로부터 크리쳐까      15714.285714
# Name: discount_price, dtype: float64

# %%
# 가장 높은 할인율을 가진 강의 찾기
max_discount_course = monthly_discount_rates.idxmax()

# 결과 출력
print(f"가장 높은 할인율을 가진 강의는 '{max_discount_course[2]}' 으로 할인율은 {monthly_discount_rates[max_discount_course]}.")
# Out:
# 가장 높은 할인율을 가진 강의는 '[내부용]Apach' 으로 할인율은 200000.0.

# %% [markdown]
# #### **(Course) 강의 키워드에서 가장 많이 언급된 단어 분석**

# %% [markdown]
# - 강의 키워드 열에서 많이 언급된 단어를 찾기 위해서는 'keywords' 열을 토큰화하여서 가장 많이 언급되고 있는 단어를 찾아야 함
# - 'keywords' 열에서 가장 많이 언급된 단어가 ','로 나타났지만, 글자가 아니기 때문에, 두번째로 많이 언급되는 단어를 구하는 코드를 사용하였으며, '평생소장'이 86회로 가장 많이 언급된 단어로 볼 수 있음

# %%
import pandas as pd
from collections import Counter
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\J\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\J\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# 'keywords' 열에서 텍스트 추출
keywords_text = ' '.join(course['keywords'].dropna())

# 텍스트 토큰화
tokens = word_tokenize(keywords_text)

# 소문자로 변환
tokens = [word.lower() for word in tokens]
tokens = [word for word in tokens if word not in stop_words]

# 단어 빈도 계산
word_counts = Counter(tokens)

# 가장 많이 언급된 단어 찾기
most_common_word = word_counts.most_common(1)[0]

print("가장 많이 언급된 단어:", most_common_word)
# Out:
# 가장 많이 언급된 단어: (',', 6317)

# %%
# 두 번째로 많이 언급된 단어 찾기
most_common_word2 = word_counts.most_common(2)[1]
print("두 번째로 많이 언급된 단어:", most_common_word2)
# Out:
# 두 번째로 많이 언급된 단어: ('평생소장', 86)

# %% [markdown]
# #### **(Refund) 환불이 가장 많은 강의 분석**

# %% [markdown]
# - 환불이 많았던 강의 ID는 213368이며, 269회 환불되었었음.

# %%
# 각 강의별 환불 횟수 계산
refund_count = refund['course_id'].value_counts()

# 환불이 가장 많은 강의
most_refund_course = refund_count.idxmax()
most_refund_count = refund_count.max()

# 결과를 테이블 형식으로 바꾸기
refund_result_df = pd.DataFrame({'강의 ID': [most_refund_course], '환불 횟수': [most_refund_count]})
print(refund_result_df)
# Out:
#       강의 ID  환불 횟수
# 0  211368.0    269

# %% [markdown]
# #### **(Customer) 강의를 가장 많이 신청한 고객과 그 금액 분석**

# %% [markdown]
# - 강의를 많이 신청한 고객의 ID는 819532였으며, 총 669만원을 지불하였음.

# %%
order.head()
# Out:
#         id   type      state        name          created_at  \
# 0  1600585  ORDER  COMPLETED  [30일 수강] 엑 2022-12-31 23:42:49
# 1  1600580  ORDER  COMPLETED  한번에 끝내는 재무 2022-12-31 23:39:01
# 2  1600579  ORDER  COMPLETED  네오아카데미 : 까 2022-12-31 23:38:31
# 3  1600577  ORDER  COMPLETED  백엔드 개발자를 위 2022-12-31 23:35:52
# 4  1600574  ORDER  COMPLETED  React Nati 2022-12-31 23:30:51
#
#             updated_at  customer_id  list_price  sale_price  discount_price  \
# 0  2022-12-31 23:42:52      1083679       10000           0           10000
# 1  2022-12-31 23:39:25       129176       40000       40000               0
# 2  2022-12-31 23:39:17      1072552       20000       10000           10000
# 3  2022-12-31 23:36:09      1083664       20000       20000           10000
# 4  2022-12-31 23:31:13      1033553       20000       20000               0
#
#    tax_free_price
# 0               0
# 1           40000
# 2           10000
# 3           20000
# 4           20000

# %%
# 'type'이 'order'인 데이터만 필터링
order_df = order[order['type'] == 'ORDER']

# 각 고객별로 신청한 강의의 총 금액을 계산
total_price_user = order.groupby('id')['list_price'].sum()

# 가장 많은 강의를 신청한 고객의 ID를 찾기
customer_with_max_courses_id = total_price_user.idxmax()

# 가장 많은 강의를 신청한 고객의 총 금액을 찾기
max_order_price = total_price_user.max()

print("가장 많은 강의를 신청한 고객의 ID:", customer_with_max_courses_id)
print("해당 고객의 총 신청 금액:", max_order_price)
# Out:
# 가장 많은 강의를 신청한 고객의 ID: 819532
# 해당 고객의 총 신청 금액: 6690000

# %% [markdown]
# #### **(Order) 주말과 주중의 평균 강의 신청율 차이**

# %% [markdown]
# - 주중에 고객들이 주말보다 약 3배 정도 많이 신청하는 것을 알 수 있었음 (주말 강의 신청율: 25.72%,
# 주중 강의 신청율: 74.28)%

# %%
# 데이터의 날짜 범위를 확인하였으며, 마지막 주문일자가 2022년 12월 31일임을 알 수 있었음.
print(order['created_at'].min())
print(order['created_at'].max())
# Out:
# 2022-01-01 00:08:19
# 2022-12-31 23:42:49

# %%
## 날짜 포맷을 %Y-%m-%d 형식으로 지정.
order["created_at"] = pd.to_datetime(order["created_at"], format='%Y-%m-%d')
order.head()
# Out:
#         id   type      state        name          created_at  \
# 0  1600585  ORDER  COMPLETED  [30일 수강] 엑 2022-12-31 23:42:49
# 1  1600580  ORDER  COMPLETED  한번에 끝내는 재무 2022-12-31 23:39:01
# 2  1600579  ORDER  COMPLETED  네오아카데미 : 까 2022-12-31 23:38:31
# 3  1600577  ORDER  COMPLETED  백엔드 개발자를 위 2022-12-31 23:35:52
# 4  1600574  ORDER  COMPLETED  React Nati 2022-12-31 23:30:51
#
#             updated_at  customer_id  list_price  sale_price  discount_price  \
# 0  2022-12-31 23:42:52      1083679       10000           0           10000
# 1  2022-12-31 23:39:25       129176       40000       40000               0
# 2  2022-12-31 23:39:17      1072552       20000       10000           10000
# 3  2022-12-31 23:36:09      1083664       20000       20000           10000
# 4  2022-12-31 23:31:13      1033553       20000       20000               0
#
#    tax_free_price
# 0               0
# 1           40000
# 2           10000
# 3           20000
# 4           20000

# %%
from datetime import timedelta
import time

order.insert(loc=5, column ='month', value=order.created_at.dt.month)
order.insert(loc=6, column ='day', value=order.created_at.dt.day)
order.insert(loc=7, column='weekday', value=order['created_at'].dt.day_name())
order.head()
# Out:
#         id   type      state        name          created_at  month  day  \
# 0  1600585  ORDER  COMPLETED  [30일 수강] 엑 2022-12-31 23:42:49     12   31
# 1  1600580  ORDER  COMPLETED  한번에 끝내는 재무 2022-12-31 23:39:01     12   31
# 2  1600579  ORDER  COMPLETED  네오아카데미 : 까 2022-12-31 23:38:31     12   31
# 3  1600577  ORDER  COMPLETED  백엔드 개발자를 위 2022-12-31 23:35:52     12   31
# 4  1600574  ORDER  COMPLETED  React Nati 2022-12-31 23:30:51     12   31
#
#     weekday           updated_at  customer_id  list_price  sale_price  \
# 0  Saturday  2022-12-31 23:42:52      1083679       10000           0
# 1  Saturday  2022-12-31 23:39:25       129176       40000       40000
# 2  Saturday  2022-12-31 23:39:17      1072552       20000       10000
# 3  Saturday  2022-12-31 23:36:09      1083664       20000       20000
# 4  Saturday  2022-12-31 23:31:13      1033553       20000       20000
#
#    discount_price  tax_free_price
# 0           10000               0
# 1               0           40000
# 2           10000           10000
# 3           10000           20000
# 4               0           20000

# %%
# 주말(토요일, 일요일)과 주중(월요일~금요일)을 구분하여 강의 신청율 계산
weekend_order = order[order['weekday'].isin(['Saturday', 'Sunday'])]
weekday_order = order[order['weekday'].isin(['Monday', 'Tuesday', 'Wednesday','Thursday','Friday'])]

# 주말과 주중의 강의 신청율 계산
weekend_order_rate = len(weekend_order) / len(order) * 100
weekday_order_rate = len(weekday_order) / len(order) * 100

print("주말 강의 신청율: {:.2f}%".format(weekend_order_rate))
print("주중 강의 신청율: {:.2f}%".format(weekday_order_rate))
# Out:
# 주말 강의 신청율: 25.72%
# 주중 강의 신청율: 74.28%

# %% [markdown]
# #### **(User) 회원 가입(created_at) 활발했던 주요 시간 분석 - 월별 차이와 그 근거 추론**

# %% [markdown]
# - 월별로 가장 활발한 회원가입 시간때는 1,2,12월은 13시, 3,10월은 5시, 6월은 6시, 나머지 달(4,5,7,8,9,11월)은 7시였음.
# - 12월~2월에 13시에 활발히 회원가입을 한 이유는 방학기간과 연관이 있어보임
#      - 보통 학교 겨울방학이 12~2월 사이이며, 사람들의 생활패턴이 평상시와 달라지기 때문으로 추정됨.
#      - 늦잠을 자고 일어나 점심을 먹고 강의를 수강하는데 관심을 보였을 것이라 생각됨
#      - 또한 아침 추위로 인해 사람들은 오후에 무언가를 하는 것을 선호하는 경향이 있음

# %%
user.head()
# Out:
#         id  type   state           created_at           updated_at  \
# 0  1075089  USER  NORMAL  2022-12-31 23:39:19  2023-12-02 00:00:22
# 1  1075079  USER  NORMAL  2022-12-31 23:08:47  2023-12-03 23:34:39
# 2  1075074  USER  NORMAL  2022-12-31 22:46:31  2023-10-19 11:49:10
# 3  1075064  USER  NORMAL  2022-12-31 22:03:14  2023-10-06 18:20:51
# 4  1075059  USER  NORMAL  2022-12-31 21:35:42  2023-02-17 01:54:52
#
#          last_login_at username
# 0  2022-12-31 23:44:35     dkfk
# 1  2023-12-03 23:34:40     toqu
# 2  2023-10-19 11:49:10     theh
# 3  2023-10-06 18:20:51     tige
# 4  2023-02-17 01:54:52     kyg6

# %%
# 'created_at' 열을 datetime 형식으로 변환
user['created_at'] = pd.to_datetime(user['created_at'])

# %%
## 날짜 포맷을 %Y-%m-%d 형식으로 지정.
user["created_at"] = pd.to_datetime(user["created_at"], format='%Y-%m-%d')

# %%
# 월별 회원가입 시간대(hour)를 추출
user['join_month'] = user['created_at'].dt.month
user['join_hour'] = user['created_at'].dt.hour

# 월별 시간대별 회원가입 수를 계산
monthly_count = user.groupby(['join_month', 'join_hour']).size()

# 가장 활발한 시간대 및 그에 해당하는 회원가입 수를 찾기
monthly_active_count_hour = monthly_count.groupby(level=0).idxmax().apply(lambda x: x[1])
monthly_active_count = monthly_count.groupby(level=0).max()

print("월별 가장 활발한 회원가입 시간대:")
print(monthly_active_count_hour)
print("\n월별 가장 활발한 회원가입 시간대에 해당하는 회원가입 수:")
print(monthly_active_count)
# Out:
# 월별 가장 활발한 회원가입 시간대:
# join_month
# 1     13
# 2     13
# 3      5
# 4      7
# 5      7
# 6      6
# 7      7
# 8      7
# 9      7
# 10     5
# 11     7
# 12    13
# dtype: int32
#
# 월별 가장 활발한 회원가입 시간대에 해당하는 회원가입 수:
# join_month
# 1      867
# 2      644
# 3      638
# 4      536
# 5      933
# 6      597
# 7      742
# 8      705
# 9      626
# 10     633
# 11     766
# 12    1029
# dtype: int64

# %% [markdown]
# #### **(Order) 강의 가격(list_price)을 5만원 단위의 도수분포표로 분석**

# %% [markdown]
# - 5만원 미만 강의 가격이 267,266개로 가장 많았으며, 670만원 미만까지로 나누어 볼 수 있었음

# %%
# list_price 열에서 5만원 단위로 반올림하여 범주화하고, 도수분포표 생성
price_distribution = order['list_price'].apply(lambda x: (x // 50000 + 1) * 50000).value_counts().sort_index()

# 결과 출력
print("도수분포표:")
for price_range, count in price_distribution.items():
    print(f"{int(price_range)}원 미만: {count}개")
# Out:
# 도수분포표:
# 50000원 미만: 267266개
# 100000원 미만: 12565개
# 150000원 미만: 3656개
# 200000원 미만: 73개
# 250000원 미만: 172개
# 300000원 미만: 4개
# 350000원 미만: 52개
# 400000원 미만: 202개
# 450000원 미만: 5개
# 500000원 미만: 4개
# 550000원 미만: 2개
# 600000원 미만: 3개
# 650000원 미만: 3개
# 750000원 미만: 1개
# 850000원 미만: 4개
# 950000원 미만: 2개
# 1150000원 미만: 5개
# 1250000원 미만: 4개
# 1300000원 미만: 1개
# 2050000원 미만: 1개
# 2550000원 미만: 1개
# 4850000원 미만: 2개
# 5300000원 미만: 3개
# 6700000원 미만: 4개

# %% [markdown]
# #### **(Order) 신청이 완료된 강의(complated)와 진행중인 강의(pending), 그리고 취소된 강의(cancelled) 간의 금액(list_price)과 유저의 비중을 월별로 각각 분석**

# %% [markdown]
# - 전체 3가지 신청 상태에서 가장 주문금액이 낮았던 달은 공통적으로 5월이었음
# - 전체 3가지 신청 상태에서 신청이 완료되거나 보류중인 강의의 주문금액이 많았던 달은 12월이었으며, 취소의 경우 1월이 가장 많았음.

# %% [markdown]
# #### **(1) 신청이 완료된(COMPLETED) 강의 기준 월별 유저 비중과 금액**

# %% [markdown]
# - 신청완료된 강의 기준으로 총 주문금액이 높았던 달은 12월로 691,980,000원이며, 유저의 비중은 27.9% 차지하였음
# - 총 주문금액이 낮았던 달은 5월로 금액은 294,430,000원으로 유저는 10.6% 차지하고 있었음

# %%
# 'state' 열에서 'COMPLETED'인 유저 수 계산
completed_id = len(order[order['state'] == 'COMPLETED'])

# 전체 유저 수
# 중복되지 않은 고유한 유저 id의 개수로 전체 유저 수를 계산
total_id = len(order['customer_id'].unique())

# 'state'가 'COMPLETED'인 유저의 비중 계산
completed_id_ratio = (completed_id / total_id)*100

print("'state'가 'COMPLETED'인 유저 수:", completed_id)
print("'state'가 'COMPLETED'인 유저의 비중:", completed_id_ratio)

# 'state'가 'completed'인 유저들의 총 주문 금액 계산
total_id_price = order[order['state'] == 'COMPLETED']['list_price'].sum()
print("'state'가 'COMPLETED'인 유저들의 총 주문 금액:", total_id_price)
# Out:
# 'state'가 'COMPLETED'인 유저 수: 176082
# 'state'가 'COMPLETED'인 유저의 비중: 173.10630265732067
# 'state'가 'COMPLETED'인 유저들의 총 주문 금액: 4828630000

# %%
# 월별로 'list_price'의 총 합과 'state'가 'completed'인 유저의 수 계산
monthly_total_price = order[order['state'] == 'COMPLETED'].groupby('month')['list_price'].sum()
monthly_completed_users = order[order['state'] == 'COMPLETED'].groupby('month').size()

# 월별로 'state'가 'COMPLETED'인 유저의 비중 계산
monthly_completed_id_ratio = (monthly_completed_users / total_id)*100

# 결과 출력
result_completed = pd.DataFrame({
    '월별 completed된 총 주문 금액': monthly_total_price,
    '월별 completed된 유저의 비중': monthly_completed_id_ratio
})

print(result_completed)
# Out:
#        월별 completed된 총 주문 금액  월별 completed된 유저의 비중
# month
# 1                  515660000             18.087083
# 2                  396660000             14.384727
# 3                  341250000             11.829648
# 4                  326280000             10.721694
# 5                  294430000             10.603722
# 6                  336600000             12.484393
# 7                  414130000             14.712099
# 8                  370250000             13.590381
# 9                  357260000             12.869769
# 10                 370320000             13.258093
# 11                 413810000             12.709523
# 12                 691980000             27.855170

# %% [markdown]
# #### **(2) 신청이 진행중인(PENDING) 강의 기준 월별 유저 비중과 금액**

# %% [markdown]
# - 신청이 보류중인 강의 중 가장 총 금액이 높은 달은 12월이었으며 176760000원이었음. 유저는 6.4% 차지하였음
# - 가장 총금액이 낮은 달은 5월로 84,820,000원이었으며, 유저는 2.9% 차지하였음.

# %%
# 'state' 열에서 'PENDING'인 유저 수 계산
pending_id = len(order[order['state'] == 'PENDING'])

# 전체 유저 수
total_id = len(order['customer_id'].unique())

# 'state'가 'PENDING'인 유저의 비중 계산
pending_id_ratio = (pending_id / total_id)*100

print("'state'가 'PENDING'인 유저 수:", pending_id)
print("'state'가 'PENDING'인 유저의 비중:", pending_id_ratio)

# 'state'가 'PENDING'인 유저들의 총 주문 금액 계산
total_id_price_pending = order[order['state'] == 'PENDING']['list_price'].sum()
print("'state'가 'PENDING'인 유저들의 총 주문 금액:", total_id_price_pending)
# Out:
# 'state'가 'PENDING'인 유저 수: 49806
# 'state'가 'PENDING'인 유저의 비중: 48.964303620759146
# 'state'가 'PENDING'인 유저들의 총 주문 금액: 1420700000

# %%
# 월별로 'list_price'의 총 합과 'state'가 'PENDING'인 유저의 수 계산
monthly_total_price = order[order['state'] == 'PENDING'].groupby('month')['list_price'].sum()
monthly_pending_users = order[order['state'] == 'PENDING'].groupby('month').size()

# 월별로 'state'가 'PENDING'인 유저의 비중 계산
monthly_pending_id_ratio = (monthly_pending_users / total_id)*100

# 결과 출력
result_pending = pd.DataFrame({
    '월별 PENDING된 총 주문 금액': monthly_total_price,
    '월별 PENDING된 유저의 비중': monthly_pending_id_ratio
})

print(result_pending)
# Out:
#        월별 PENDING된 총 주문 금액  월별 PENDING된 유저의 비중
# month
# 1                157970000            5.255655
# 2                101860000            3.742664
# 3                 95090000            3.306167
# 4                106080000            3.162634
# 5                 84820000            2.945369
# 6                102510000            3.847855
# 7                124670000            3.877348
# 8                149980000            5.628250
# 9                115070000            4.017932
# 10               100100000            3.404477
# 11               105790000            3.395629
# 12               176760000            6.380322

# %% [markdown]
# #### **(3) 신청이 취소된 강의(CANCELLED) 강의 기준 월별 유저 비중과 금액**

# %% [markdown]
# - 신청이 취소된 강의를 대상으로 분석했을 때 1월이 218,380,000원으로 가장 금액이 높았으며, 유저의 약 6.9%를 차지하였음
# - 가장 낮은 금액을 기록한 것은 5월로 105,310,000원이었고, 유저의 3.3%를 차지하였음

# %%
# 'state' 열에서 'CANCELLED'인 유저 수 계산
CANCELLED_id = len(order[order['state'] == 'CANCELLED'])

# 전체 유저 수
total_id = len(order['customer_id'].unique())

# 'state'가 'CANCELLED'인 유저의 비중 계산
CANCELLED_id_ratio = (CANCELLED_id / total_id)*100

print("'state'가 'CANCELLED'인 유저 수:", CANCELLED_id)
print("'state'가 'CANCELLED'인 유저의 비중:", CANCELLED_id_ratio)

# 'state'가 'CANCELLED'인 유저들의 총 주문 금액 계산
total_id_price_CANCELLED = order[order['state'] == 'CANCELLED']['list_price'].sum()
print("'state'가 'CANCELLED'인 유저들의 총 주문 금액:", total_id_price_CANCELLED)
# Out:
# 'state'가 'CANCELLED'인 유저 수: 58147
# 'state'가 'CANCELLED'인 유저의 비중: 57.16434491098025
# 'state'가 'CANCELLED'인 유저들의 총 주문 금액: 1780780000

# %%
# 월별로 'list_price'의 총 합과 'state'가 'CANCELLED'인 유저의 수 계산
monthly_CANCELLED_total_price = order[order['state'] == 'CANCELLED'].groupby('month')['list_price'].sum()
monthly_CANCELLED_users = order[order['state'] == 'CANCELLED'].groupby('month').size()

# 월별로 'state'가 'PENDING'인 유저의 비중 계산
monthly_CANCELLED_id_ratio = (monthly_CANCELLED_users / total_id)*100

# 결과 출력
result_CANCELLED = pd.DataFrame({
    '월별 CANCELLED된 총 주문 금액': monthly_CANCELLED_total_price,
    '월별 CANCELLED된 유저의 비중': monthly_CANCELLED_id_ratio
})

print(result_CANCELLED)
# Out:
#        월별 CANCELLED된 총 주문 금액  월별 CANCELLED된 유저의 비중
# month
# 1                  218380000              6.863025
# 2                  140410000              4.904688
# 3                  138870000              4.517347
# 4                  132670000              3.921588
# 5                  105310000              3.316981
# 6                  126730000              4.310896
# 7                  166920000              4.762139
# 8                  142310000              5.003982
# 9                  149670000              4.957776
# 10                 131900000              4.462293
# 11                 146690000              4.591079
# 12                 180920000              5.552552

# %% [markdown]
# #### **(User) state이 HIBERNATED 된 Used들이 ID를 생성(created_at)한 후 마지막 로그인(last_login_at)까지 평균적으로 걸린 일자 분석**

# %% [markdown]
# - 평균적으로 id를 생성한 후 마지막 로그인까지 154일이 걸렸음

# %%
user.head()
# Out:
#         id  type   state          created_at           updated_at  \
# 0  1075089  USER  NORMAL 2022-12-31 23:39:19  2023-12-02 00:00:22
# 1  1075079  USER  NORMAL 2022-12-31 23:08:47  2023-12-03 23:34:39
# 2  1075074  USER  NORMAL 2022-12-31 22:46:31  2023-10-19 11:49:10
# 3  1075064  USER  NORMAL 2022-12-31 22:03:14  2023-10-06 18:20:51
# 4  1075059  USER  NORMAL 2022-12-31 21:35:42  2023-02-17 01:54:52
#
#          last_login_at username  join_month  join_hour
# 0  2022-12-31 23:44:35     dkfk          12         23
# 1  2023-12-03 23:34:40     toqu          12         23
# 2  2023-10-19 11:49:10     theh          12         22
# 3  2023-10-06 18:20:51     tige          12         22
# 4  2023-02-17 01:54:52     kyg6          12         21

# %%
# 'created_at' 열과 'last_login_at' 열을 datetime 형식으로 변환
user['created_at'] = pd.to_datetime(user['created_at'])
user['last_login_at'] = pd.to_datetime(user['last_login_at'])

# 'state'가 'HIBERNATED'인 사용자들만 필터링
hibernated_users = user[user['state'] == 'HIBERNATED']

# ID 생성일(created_at)부터 마지막 로그인일(last_login_at)까지의 기간 계산 및 새로운 열 추가
hibernated_users['duration'] = hibernated_users['last_login_at'] - hibernated_users['created_at']

# 결과 출력
print(hibernated_users.head())
# Out:
#            id  type       state          created_at           updated_at  \
# 4112  1060441  USER  HIBERNATED 2022-12-22 02:47:50  2023-12-22 03:00:26
# 4115  1060433  USER  HIBERNATED 2022-12-22 02:35:53  2023-12-22 03:00:26
# 4121  1060422  USER  HIBERNATED 2022-12-22 02:30:07  2023-12-22 03:00:26
# 4123  1060418  USER  HIBERNATED 2022-12-22 02:28:07  2023-12-22 03:00:26
# 4124  1060415  USER  HIBERNATED 2022-12-22 02:23:09  2023-12-22 03:00:26
#
#            last_login_at username  join_month  join_hour        duration
# 4112 2022-12-22 02:47:51     fire          12          2 0 days 00:00:01
# 4115 2022-12-22 02:35:53     dlsd          12          2 0 days 00:00:00
# 4121 2022-12-22 02:30:22     ever          12          2 0 days 00:00:15
# 4123 2022-12-22 02:35:29     yong          12          2 0 days 00:07:22
# 4124 2022-12-22 02:28:48     ssm7          12          2 0 days 00:05:39
# C:\Users\J\AppData\Local\Temp\ipykernel_8636\2567741124.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hibernated_users['duration'] = hibernated_users['last_login_at'] - hibernated_users['created_at']

# %%
average_duration = hibernated_users['last_login_at'] - hibernated_users['created_at']
print("평균 접속일:", average_duration.mean())
# Out:
# 평균 접속일: 154 days 11:33:28.358140552

# %% [markdown]
# ## **Trend Analysis**

# %% [markdown]
# ### **4) 2022년 1월부터 12월까지 trend 분석**

# %% [markdown]
# ####  **(order 데이터) 월별 강의 가격(list_price)과 판매가격(sale_price) 비교**

# %% [markdown]
# - order 데이터는 2022년 데이터로만 이루어져 있었음
# - 강의 가격(list_price)과 판매가격(sale_price)를 비교했을 때 두 가격 간의 차이가 12월(348,080,000원)이 가장 컸으며, 6월(57,600,000원)이 가장 작았음

# %%
order.head()
# Out:
#         id   type      state        name          created_at  month  day  \
# 0  1600585  ORDER  COMPLETED  [30일 수강] 엑 2022-12-31 23:42:49     12   31
# 1  1600580  ORDER  COMPLETED  한번에 끝내는 재무 2022-12-31 23:39:01     12   31
# 2  1600579  ORDER  COMPLETED  네오아카데미 : 까 2022-12-31 23:38:31     12   31
# 3  1600577  ORDER  COMPLETED  백엔드 개발자를 위 2022-12-31 23:35:52     12   31
# 4  1600574  ORDER  COMPLETED  React Nati 2022-12-31 23:30:51     12   31
#
#     weekday           updated_at  customer_id  list_price  sale_price  \
# 0  Saturday  2022-12-31 23:42:52      1083679       10000           0
# 1  Saturday  2022-12-31 23:39:25       129176       40000       40000
# 2  Saturday  2022-12-31 23:39:17      1072552       20000       10000
# 3  Saturday  2022-12-31 23:36:09      1083664       20000       20000
# 4  Saturday  2022-12-31 23:31:13      1033553       20000       20000
#
#    discount_price  tax_free_price
# 0           10000               0
# 1               0           40000
# 2           10000           10000
# 3           10000           20000
# 4               0           20000

# %%
print(order["created_at"].min())
print(order["created_at"].max())
# Out:
# 2022-01-01 00:08:19
# 2022-12-31 23:42:49

# %%
order[["id", "month", "sale_price"]].head()
# Out:
#         id  month  sale_price
# 0  1600585     12           0
# 1  1600580     12       40000
# 2  1600579     12       10000
# 3  1600577     12       20000
# 4  1600574     12       20000

# %%
monthly_data = pd.pivot_table(order, index='month', values=['list_price','sale_price', 'discount_price'], aggfunc='sum')
monthly_data
# Out:
#        discount_price  list_price  sale_price
# month
# 1           215690000   892010000   752110000
# 2           162770000   638930000   522490000
# 3           122360000   575210000   503870000
# 4           109240000   565030000   497270000
# 5           127200000   484560000   416870000
# 6           106710000   565840000   508240000
# 7           166070000   705720000   604920000
# 8           163210000   662540000   592520000
# 9           133730000   622000000   565350000
# 10          181460000   602320000   488960000
# 11          180170000   666290000   538680000
# 12          423880000  1049660000   701580000

# %%
plt.plot(monthly_data.index, monthly_data['list_price'], label='list_price')
plt.plot(monthly_data.index, monthly_data['sale_price'], label='sale_price')

plt.xlabel('Month')
plt.ylabel('Price')
plt.title('Monthly List Price and Sale Price')
plt.legend()

plt.show()

# %% [markdown]
# #### **(course 데이터) 월별 진행중인(Ongoing) 강의와 보류중인(Pending) 강의 비교**

# %% [markdown]
# - course 데이터는 2018년부터 2022년까지 있었기 때문에 2022년 데이터만 필터링하여 분석함
# - 2022년 기준 보류중인(pending) id보다 강의 수강을 진행중인(ongoing) id가 많음을 알 수 있었음

# %%
course.head()
# Out:
#        id    type    state        created_at        updated_at  \
# 0  214903  COURSE  ONGOING   2022-12-27 1:33   2022-12-27 1:33
# 1  214898  COURSE  ONGOING  2022-12-26 12:25  2022-12-26 12:25
# 2  214897  COURSE  ONGOING  2022-12-26 12:20  2022-12-26 12:20
# 3  214896  COURSE  ONGOING  2022-12-26 12:17  2022-12-26 12:17
# 4  214895  COURSE  ONGOING  2022-12-26 12:14  2022-12-26 12:14
#
#                title description close_at  total_class_hours keywords
# 0  (B2G) K-Di-214903         NaN      NaN                NaN      NaN
# 1  (B2G) K-Di-214898         NaN      NaN                NaN      NaN
# 2  (B2G) K-Di-214897         NaN      NaN                NaN      NaN
# 3  (B2G) K-Di-214896         NaN      NaN                NaN      NaN
# 4  (B2G) K-Di-214895         NaN      NaN                NaN      NaN

# %%
print(course["created_at"].min())
print(course["created_at"].max())
# Out:
# 2018-05-03 1:19
# 2022-12-27 1:33

# %%
course["created_at"] = pd.to_datetime(course["created_at"])
course["created_month"] = course["created_at"].dt.strftime("%Y%m")
print(course[["id","state","created_month"]].head())
# Out:
#        id    state created_month
# 0  214903  ONGOING        202212
# 1  214898  ONGOING        202212
# 2  214897  ONGOING        202212
# 3  214896  ONGOING        202212
# 4  214895  ONGOING        202212

# %%
# 2022년 1월부터 12월까지의 데이터만 필터링
course_filtered = course[(course['created_at'] >= '2022-01-01') & (course['created_at'] <= '2022-12-31')]

# 'ONGOING'와 'PENDING' 상태인 경우에 해당하는 데이터만 필터링
course_filtered = course_filtered[(course_filtered['state'] == 'ONGOING') | (course_filtered['state'] == 'PENDING')]

# 월별로 강의가 진행중인 ID의 총 개수 계산
monthly_counts = course_filtered.groupby(['created_at', 'state']).size().unstack(fill_value=0)

# 월별 추세선을 나타내는 그래프 그리기
monthly_counts.plot(marker='o', figsize=(10, 6))

# 그래프 꾸미기
plt.title('Trend of Course State per Month (2022)')
plt.xlabel('Month')
plt.ylabel('Number of Courses')
plt.xticks(rotation=45)
plt.legend(title='State')
plt.grid(True)
plt.tight_layout()

# 그래프 표시
plt.show()

# %% [markdown]
# #### **(user 데이터) 가입 후 마지막 로그인날까지 기간**

# %% [markdown]
# - 2022년 기준으로 했을 때 USER들은 신규가입 후 마지막 로그인날까지 50일이 되지 않았을 때 다시 접속하는 것을 알 수 있음
# - 그 숫자는 22,701명임.
# - 최대 350일까지 다시 접속하는데 걸린 유저들은 210명 정도로 매우 적음

# %%
user.head()
# Out:
#         id  type   state          created_at           updated_at  \
# 0  1075089  USER  NORMAL 2022-12-31 23:39:19  2023-12-02 00:00:22
# 1  1075079  USER  NORMAL 2022-12-31 23:08:47  2023-12-03 23:34:39
# 2  1075074  USER  NORMAL 2022-12-31 22:46:31  2023-10-19 11:49:10
# 3  1075064  USER  NORMAL 2022-12-31 22:03:14  2023-10-06 18:20:51
# 4  1075059  USER  NORMAL 2022-12-31 21:35:42  2023-02-17 01:54:52
#
#         last_login_at username  join_month  join_hour
# 0 2022-12-31 23:44:35     dkfk          12         23
# 1 2023-12-03 23:34:40     toqu          12         23
# 2 2023-10-19 11:49:10     theh          12         22
# 3 2023-10-06 18:20:51     tige          12         22
# 4 2023-02-17 01:54:52     kyg6          12         21

# %%
print(user["created_at"].min())
print(user["created_at"].max())
# Out:
# 2019-07-01 23:49:35
# 2022-12-31 23:39:19

# %%
print(user["last_login_at"].min())
print(user["last_login_at"].max())
# Out:
# 2021-11-14 12:00:19
# 2024-01-26 02:03:42

# %%
# 2022년 1월부터 12월까지의 데이터만 필터링
user_filtered = user[(user['created_at'] >= '2022-01-01') & (user['created_at'] <= '2022-12-31')]

# 'state'가 'HIBERNATED'인 사용자들만 필터링
hibernated_users = user_filtered[user_filtered['state'] == 'HIBERNATED']

# ID 생성일(created_at)부터 마지막 로그인일(last_login_at)까지의 기간 계산 및 새로운 열 추가
hibernated_users['duration'] = (hibernated_users['last_login_at'] - hibernated_users['created_at']).dt.days

# last_login_at와 created_at이 동일한 경우에는 duration을 0으로 설정
hibernated_users.loc[hibernated_users['last_login_at'] == hibernated_users['created_at'], 'duration'] = 0

# 그래프 그리기
n, bins, patches = plt.hist(hibernated_users['duration'], bins=10, color='skyblue', edgecolor='black')

# 그래프 꾸미기
plt.title('Distribution of Hibernated User Durations')
plt.xlabel('Duration (days)')
plt.ylabel('Frequency')

# 각 구간에 숫자 표시
for i in range(len(patches)):
    plt.text(x=bins[i], y=n[i], s=int(n[i]), ha='center', va='bottom')

# 그래프 표시
plt.show()
# Out:
# C:\Users\J\AppData\Local\Temp\ipykernel_8636\2538641968.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hibernated_users['duration'] = (hibernated_users['last_login_at'] - hibernated_users['created_at']).dt.days

# %% [markdown]
# #### **(customer 데이터) 월별 가입 유저수 추세**

# %% [markdown]
# - 1월 9332명, 12월 8587명 순으로 가장 많은 가입을 했음음 볼 수 있었으며, 가장 가입 유저가 적었던 달은 5월로 5,185명이었음
# - 전체적으로 1월에서 5월 사이는 하락세를 보였고, 5월에서 8월까지는 다시 상승하지만 8월~11월까지 다시 하락세를 보였음

# %%
customer.head()
# Out:
#         id  type   state       created_at        updated_at  user_id  \
# 0  1482394  USER  NORMAL  2024/01/24 4:44  2024/01/24 13:54   959919
# 1  1482300  USER  NORMAL  2024/01/24 4:43   2024/01/25 6:10   818301
# 2  1482071  USER  NORMAL  2024/01/24 4:41   2024/01/25 7:46   543671
# 3  1445268  USER  NORMAL  2023/12/27 4:17   2023/12/27 4:17   824733
# 4  1445150  USER  NORMAL  2023/12/27 4:15   2023/12/27 4:15   767404
#
#            name       phone                           email
# 0  USER_1482394  1012345678  USER_1482394@notexistemail.com
# 1  USER_1482300  1012345678  USER_1482300@notexistemail.com
# 2  USER_1482071  1012345678  USER_1482071@notexistemail.com
# 3  USER_1445268  1012345678  USER_1445268@notexistemail.com
# 4  USER_1445150  1012345678  USER_1445150@notexistemail.com

# %%
print(customer["created_at"].min())
print(customer["created_at"].max())
# Out:
# 2015/02/14 15:00
# 2024/01/24 4:44

# %%
print(customer["updated_at"].min())
print(customer["updated_at"].max())
# Out:
# 2019/09/18 0:55
# 2024/01/26 0:00

# %%
# 'created_at' 열과 'updated_at' 열을 datetime 형식으로 변환
customer['created_at'] = pd.to_datetime(customer['created_at'])
customer['updated_at'] = pd.to_datetime(customer['updated_at'])

# 가입일(created_at)부터 이후 수정일(updated_at)까지의 기간을 계산하여 새로운 열 추가
customer['days_since_creation'] = (customer['updated_at'] - customer['created_at']).dt.days

# 결과 출력
customer.head()
# Out:
#         id  type   state          created_at          updated_at  user_id  \
# 0  1482394  USER  NORMAL 2024-01-24 04:44:00 2024-01-24 13:54:00   959919
# 1  1482300  USER  NORMAL 2024-01-24 04:43:00 2024-01-25 06:10:00   818301
# 2  1482071  USER  NORMAL 2024-01-24 04:41:00 2024-01-25 07:46:00   543671
# 3  1445268  USER  NORMAL 2023-12-27 04:17:00 2023-12-27 04:17:00   824733
# 4  1445150  USER  NORMAL 2023-12-27 04:15:00 2023-12-27 04:15:00   767404
#
#            name       phone                           email  \
# 0  USER_1482394  1012345678  USER_1482394@notexistemail.com
# 1  USER_1482300  1012345678  USER_1482300@notexistemail.com
# 2  USER_1482071  1012345678  USER_1482071@notexistemail.com
# 3  USER_1445268  1012345678  USER_1445268@notexistemail.com
# 4  USER_1445150  1012345678  USER_1445150@notexistemail.com
#
#    days_since_creation
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    0

# %%
customer["created_month"] = customer["created_at"].dt.strftime("%Y%m")

# %%
# 2022년 1월부터 12월까지 데이터만 필터링
customer_filtered = customer[(customer['created_at'] >= '2022-01-01') & (customer['created_at'] <= '2022-12-31')]

# 월별로 user_id의 개수를 카운팅하여 새로운 열 추가
count_by_month = customer_filtered.groupby(customer_filtered['created_at'].dt.strftime('%Y-%m'))['user_id'].count().reset_index()
count_by_month.columns = ['created_month', 'user_count']

# 결과 출력
print(count_by_month)
# Out:
#    created_month  user_count
# 0        2022-01        9332
# 1        2022-02        6058
# 2        2022-03        6294
# 3        2022-04        5310
# 4        2022-05        5185
# 5        2022-06        5707
# 6        2022-07        6967
# 7        2022-08        7570
# 8        2022-09        6691
# 9        2022-10        5676
# 10       2022-11        5734
# 11       2022-12        8587

# %%
# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(count_by_month['created_month'], count_by_month['user_count'], marker='o', color='g', linestyle='-')
plt.title('Monthly User Join Count in 2022')
plt.xlabel('Month')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# 그래프 표시
plt.show()

# %% [markdown]
# #### **(refund 데이터) 월별 환불 강의수와 금액 분석**

# %% [markdown]
# - REFUND 데이터는 2022년 1월 3일부터 12월 30일까지 구성되었으며, state가 completed되었으며, type이 ADMIN_AUTO_REFUND 데이터만 존재하였음
# - 환불은 1월과 12월에 많이 일어났으며, 그 금액도 2,300,000원 이상이었음. 적은 달은 3월로 774개 강의가 14,900,000원 환불되었음
# - 반면 10월에는 906개 강의가 환불되었지만 그 금액은 14,990,000원으로 적은 액수가 환불되었음

# %%
refund.head()
# Out:
#       id               type      state       created_at       updated_at  \
# 0  72124  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 7:29  2022-12-30 7:29
# 1  72121  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 7:01  2022-12-30 7:01
# 2  72119  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 6:08  2022-12-30 6:08
# 3  72117  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 6:00  2022-12-30 6:00
# 4  72116  ADMIN_AUTO_REFUND  COMPLETED  2022-12-30 5:57  2022-12-30 5:57
#
#      user_id  course_id  amount  tax_free_amount
# 0   619833.0   214323.0  -20000           -20000
# 1   146614.0   213905.0  -10000           -10000
# 2   541404.0   214402.0       0                0
# 3  1056095.0   203935.0  -10000           -10000
# 4    98880.0   213244.0  -20000           -20000

# %%
print(refund["created_at"].min())
print(refund["created_at"].max())
# Out:
# 2022-01-03 1:04
# 2022-12-30 7:29

# %%
# state 열의 고유값 확인
state_refund = refund['state'].unique()

# 결과 출력
print(state_refund)
# Out:
# ['COMPLETED']

# %%
# type 열의 고유값 확인
type_refund = refund['type'].unique()

# 결과 출력
print(type_refund)
# Out:
# ['ADMIN_AUTO_REFUND']

# %%
refund["created_at"] = pd.to_datetime(refund["created_at"])
refund.insert(loc=5, column ='created_month', value=refund.created_at.dt.month)

# %%
# 'created_month'를 기준으로 'course_id'와 'amount' 합계 계산
refund_df = refund.groupby('created_month').agg({'course_id': 'count', 'amount': 'sum'})

# 결과 출력
print(refund_df)
# Out:
#                course_id    amount
# created_month
# 1                   1369 -23490000
# 2                   1066 -17940000
# 3                    774 -14900000
# 4                    892 -18660000
# 5                    802 -15450000
# 6                    908 -15440000
# 7                    957 -17960000
# 8                    983 -15740000
# 9                   1074 -19110000
# 10                   906 -14990000
# 11                  1012 -20370000
# 12                  1332 -24920000

# %%
# 그래프 크기 설정
plt.figure(figsize=(10, 6))

# 그래프 그리기
fig, ax1 = plt.subplots()

# refund course_id 수 선 그래프
ax1.plot(refund_df.index, refund_df['course_id'], color='tab:blue', marker='o', label='Refund Course_id Count')
ax1.set_xlabel('Month', fontsize=10)
ax1.set_ylabel('Refund Course_id Count', color='tab:blue')
ax1.tick_params('y', colors='tab:blue')

# refund amount 합계 바 그래프
ax2 = ax1.twinx()
ax2.bar(refund_df.index, refund_df['amount'], color='tab:red', alpha=0.5, label='Refund_Amount')
ax2.set_ylabel('Refund_Amount', color='tab:red')
ax2.tick_params('y', colors='tab:red')

# 그래프 제목 설정
plt.title('Monthly Number of Refund and Amount in 2022')

# 범례 표시
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# 그래프 표시
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# ## **3. 분석종합 및 결론**

# %% [markdown]
# ### **1) 분석 종합**

# %% [markdown]
# **- (Order) 2022년 1월 중 가장 매출이 높았던 3일과 낮았던 3일의 매출액(list_price)과, 주문 수, 신청자 수, 강의 수**
#   -	가장 매출이 높았던 3일
#    - 2022-01-03 48,980,000원, 2022-01-07 34,700,000원, 2022-01-05 33,840,000원
#    - 주문 수: 3,876개, 신청자 수: 4,444명, 강의 수: 971개
#   -	가장 매출이 낮았던 3일
#    - 2022-01-01 6,260,000원, 2022-01-22 ,685,000원, 2022-01-29 , 89,200원
#    - 주문 수: 703개, 신청 수:787명 강의수:174개
#
# **- (Order) 월별 각 강의 별 할인율 분석**
#   - 각 월별 각 강의별 할인율을 계산하였으며, 그 중 가장 높은 할인율을 가진 강의는 '[내부용]Apach' 으로 할인율은 200000.0.
#
# **- (Course) 강의 키워드에서 가장 많이 언급된 단어 분석**
#    - 강의 키워드 열에서 많이 언급된 단어를 찾기 위해서는 'keywords' 열을 토큰화하여서 가장 많이 언급되고 있는 단어를 찾아야 함
#    - 'keywords' 열에서 가장 많이 언급된 단어가 ','로 나타났지만, 글자가 아니기 때문에, 두번째로 많이 언급되는 단어를 구하는 코드를 사용하였으며, '평생소장'이 86회로 가장 많이 언급된 단어로 볼 수 있음
#
# **- (Refund) 환불이 가장 많은 강의 분석**
#   -	환불이 많았던 강의 ID는 213368이며, 269회 환불되었었음.
#
# **- (Customer) 강의를 가장 많이 신청한 고객과 그 금액 분석**
#   - 강의를 많이 신청한 고객의 ID는 819532였으며, 총 669만원을 지불하였음.
#
# **- (Order) 주말과 주중의 평균 강의 신청율 차이**
#   -	주중에 고객들이 주말보다 약 3배 정도 많이 신청하는 것을 알 수 있었음
#   - 주말 강의 신청율: 25.72%, 주중 강의 신청율: 74.28%
#
# **- (User) 회원 가입(created_at) 활발했던 주요 시간 분석 - 월별 차이와 그 근거 추론**
#   - 월별로 가장 활발한 회원가입 시간때는 1,2,12월은 13시, 3,10월은 5시, 6월은 6시, 나머지 달(4,5,7,8,9,11월)은 7시였음.
#   - 12월~2월에 13시에 활발히 회원가입을 한 이유는 방학기간과 연관이 있어보임
#   - 보통 학교 겨울방학이 12~2월 사이이며, 사람들의 생활패턴이 평상시와 달라지기 때문으로 추정됨.
#   - 늦잠을 자고 일어나 점심을 먹고 강의를 수강하는데 관심을 보였을 것이라 생각됨
#   - 또한 아침 추위로 인해 사람들은 오후에 무언가를 하는 것을 선호하는 경향이 있음
#
# **- (Order) 강의 가격(list_price)을 5만원 단위의 도수분포표로 분석**
#   - 5만원 미만 강의 가격이 267,266개로 가장 많았으며, 670만원 미만까지로 나누어 볼 수 있었음
#
# **- (Order) 신청이 완료된 강의(complated)와 진행중인 강의(pending), 그리고 취소된 강의(cancelled) 간의 금액(list_price)과 유저의 비중을 월별로 각각 분석**
#   - 전체 3가지 신청 상태에서 가장 주문금액이 낮았던 달은 공통적으로 5월이었음
#   - 전체 3가지 신청 상태에서 신청이 완료되거나 보류중인 강의의 주문금액이 많았던 달은 12월이었으며, 취소의 경우 1월이 가장 많았음.
#
#    - (1) 신청이 완료된(COMPLETED) 강의 기준 월별 유저 비중과 금액
#      - 신청완료된 강의 기준으로 총 주문금액이 높았던 달은 12월로 691,980,000원이며, 유저의 비중은 27.9% 차지하였음
#      - 총 주문금액이 낮았던 달은 5월로 금액은 294,430,000원으로 유저는 10.6% 차지하고 있었음
#    - (2) 신청이 진행중인(PENDING) 강의 기준 월별 유저 비중과 금액
#      - 신청이 보류중인 강의 중 가장 총 금액이 높은 달은 12월이었으며 176,760,000원이었음. 유저는 6.4% 차지하였음
#      - 가장 총금액이 낮은 달은 5월로 84,820,000원이었으며, 유저는 2.9% 차지하였음.
#    - (3) 신청이 취소된 강의(CANCELLED) 강의 기준 월별 유저 비중과 금액
#      -	신청이 취소된 강의를 대상으로 분석했을 때 1월이 218,380,000원으로 가장 금액이 높았으며, 유저의 약 6.9%를 차지하였음
#      - 가장 낮은 금액을 기록한 것은 5월로 105,310,000원이었고, 유저의 3.3%를 차지하였음
#
# - (User) state이 HIBERNATED 된 Used들이 ID를 생성(created_at)한 후 마지막 로그인(last_login_at)까지 평균적으로 걸린 일자 분석
#   - 평균적으로 id를 생성한 후 마지막 로그인까지 154일이 걸렸음
#
# **2022년 1월부터 12월까지 trend 분석**
# - (order 데이터) 월별 강의 가격(list_price)과 판매가격(sale_price) 비교
#   -	order 데이터는 2022년 데이터로만 이루어져 있었음
#   - 강의 가격(list_price)과 판매가격(sale_price)를 비교했을 때 두 가격 간의 차이가 12월(348,080,000원)이 가장 컸으며, 6월(57,600,000원)이 가장 작았음
# - (course 데이터) 월별 진행중인(Ongoing) 강의와 보류중인(Pending) 강의 비교
#   - course 데이터는 2018년부터 2022년까지 있었기 때문에 2022년 데이터만 필터링하여 분석함
#   - 2022년 기준 보류중인(pending) id보다 강의 수강을 진행중인(ongoing) id가 많음을 알 수 있었음
# - (user 데이터) 가입 후 마지막 로그인날까지 기간
#   - 2022년 기준으로 했을 때 USER들은 신규가입 후 마지막 로그인날까지 50일이 되지 않았을 때 다시 접속하는 것을 알 수 있음
#   - 그 숫자는 22,701명임.
#   -	최대 350일까지 다시 접속하는데 걸린 유저들은 210명 정도로 매우 적음
# - (customer 데이터) 월별 가입 유저수 추세
#   - 1월 9332명, 12월 8587명 순으로 가장 많은 가입을 했음음 볼 수 있었으며, 가장 가입 유저가 적었던 달은 5월로 5,185명이었음
#   - 전체적으로 1월에서 5월 사이는 하락세를 보였고, 5월에서 8월까지는 다시 상승하지만 8월~11월까지 다시 하락세를 보였음
# - (refund 데이터) 월별 환불 강의수와 금액 분석
#   - REFUND 데이터는 2022년 1월 3일부터 12월 30일까지 구성되었으며, state가 completed되었으며, type이 ADMIN_AUTO_REFUND 데이터만 존재하였음
#   - 환불은 1월과 12월에 많이 일어났으며, 그 금액도 2,300,000원 이상이었음. 적은 달은 3월로 774개 강의가 14,900,000원 환불되었음
#   - 반면 10월에는 906개 강의가 환불되었지만 그 금액은 14,990,000원으로 적은 액수가 환불되었음

# %% [markdown]
# ### **2) 결론**

# %% [markdown]
# o	결론
# - 주중보다 주말에 고객들이 많이 약 3배 많이 신청하는 경향이 있음.
#   - 이를 위해 주중에 충분한 강의가격할인 홍보 등을 통해 인지시키면서 주중에 강의할인쿠폰을 배부하여 주말에 더 많은 고객들이 신청할 수 있게 유도 필요
#   - 유저들은 대부분 가입하고 50일이 걸리지 않고 다시 재접속함을 알 수 있어 이를 고려하여 휴면상태인 고객들에게도 쿠폰 혹은 할인알림등을 보낼 필요 있음.
# - 12월에 강의 주문금액이 많은만큼 실제강의가격과 판매가격 간의 차이가 크며 환불도 많이 발생함. 1, 2월에는 강의 신청수가 많지만 1월에는 환불이 많이 일어남
# - 회원들이 회원가입이 활발한 기간은 12,1,2월이 13시였음. 나머지 월들은 5-7시 사이인 것을 고려해 시간별 강의 수강 유도 전략 필요
#   - 12~2월 사이는 방학, 휴가 등이 많은 시기이므로 이 시기에 맞춰 강의를 수강하고 직무 혹은 학습 역량을 강화하기 위해 강의를 듣는 경향이 있다고 봄
#   - 하지만 평소와는 다른 방학, 휴가 등의 시간을 보내므로 사람들의 행동패턴이 달라져 점심 이후 오후 시간때 강의를 듣기를 원하는 사람이 많은 것으로 추정됨
# - 또한 강의 신청 완료, 보류, 취소 상태의 주문금액이 공통적으로 가장 낮았던 5월이었기에 원인 파악 및 강의 구매율을 높이기 위한 방안 마련 필요
#
# o	기대효과
#   - 다양한 형태의 데이터 분석으로 강의 주문, 수강, 선호 요일 등 특징 파악이 가능하여 고객들의 패턴 파악 가능
#   - 고객들의 전체적인 패턴파악으로 인해 환불 금액 감소, 타사 이탈 방지 등 대책 수립 가능
#
# o	Lesson and Learned
#   - 데이터 전처리의 중요성과 각 강의관련 데이터별 특징 이해
#   - 여러가지 형태의 분석결과 도출로 고객 데이터 다룰 수 있는 능력향상
